# %%
# !pip install korpora

# %%
import torch
import random
import numpy as np
import torch.backends.cudnn as cudnn

torch.manual_seed(42)
torch.cuda.manual_seed(42)
torch.cuda.manual_seed_all(42)
np.random.seed(42)
cudnn.benchmark = False
cudnn.deterministic = True
random.seed(42)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %%
# !git clone https://github.com/kmounlp/NER.git
# Out:
# Cloning into 'NER'...
# remote: Enumerating objects: 1770, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 1770 (delta 0), reused 42 (delta 0), pack-reused 1727
# Receiving objects: 100% (1770/1770), 20.69 MiB | 15.79 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
import os
import glob

# %%
file_list=[]

# %%
for x in os.walk('NER/'):
  for y in glob.glob(os.path.join(x[0], '*_NER.txt')):
    file_list.append(y)

# %%
file_list = sorted(file_list)

# %%
from pathlib import Path

file_path = file_list[0]
file_path = Path(file_path)
raw_text = file_path.read_text().strip()

# %%
from Korpora import Korpora
corpus = Korpora.load("naver_changwon_ner")
# Out:
#     Korpora 는 다른 분들이 연구 목적으로 공유해주신 말뭉치들을
#     손쉽게 다운로드, 사용할 수 있는 기능만을 제공합니다.
#
#     말뭉치들을 공유해 주신 분들에게 감사드리며, 각 말뭉치 별 설명과 라이센스를 공유 드립니다.
#     해당 말뭉치에 대해 자세히 알고 싶으신 분은 아래의 description 을 참고,
#     해당 말뭉치를 연구/상용의 목적으로 이용하실 때에는 아래의 라이센스를 참고해 주시기 바랍니다.
#
#     # Description
#     Author : 네이버 + 창원대
#     Repository : https://github.com/naver/nlp-challenge/tree/master/missions/ner
#     References : http://air.changwon.ac.kr/?page_id=10
#
#     개체명(Named Entity)은 인명, 기관명, 지명 등과 같이 문장 또는 문서에서 특정한 의미를 가지고 있는 단어 또는 어구를 말합니다.
#     이 때문에 개체명은 정보 검색 및 언어 이해를 위한 분석에서 주요한 대상으로 다루어지고 있습니다.
#     Data.ly에서는 개체명 코퍼스를 제공하여 연구에 도움을 드리고자 하며, 공개적인 리더보드를 통해 많은 분들의 연구 동향을 논의/공유하고자 합니다.
#     제공되는 코퍼스는 Data.ly에서 제작한 것으로, 연구 및 리더보드를 위한 학습으로 사용 가능하며 상업적인 목적으로 사용될 수 없습니다.
#
#     # License
#     연구 및 리더보드를 위한 학습으로 사용 가능하며 상업적인 목적으로 사용될 수 없습니다.
#
# [Korpora] Corpus `naver_changwon_ner` is already installed at /root/Korpora/naver_changwon_ner/train_data

# %% [markdown]
# 네이버 데이터셋 전처리

# %%
def naver_read_file(file_list):

    token_docs = []
    tag_docs = []

    for doc in file_list:
        tokens = []
        tags = []
        list1=doc.words
        list2=doc.tags

        for text,tag in zip(list1,list2):
            if(tag in ['DAT_B', 'DUR_B', 'TIM_B']):
                token = text
                print(tag, token, text)
            else:
                token = text
                tag = 'O'
                print(tag, token, text)

            for i, syllable in enumerate(text): # 음절 단위로 자르고
                tokens.append(syllable)
                if tag == '-':
                  tag = 'O' # 태그가 '-'인 경우 'O'로 변경
                tags.append(tag)

        token_docs.append(tokens)
        tag_docs.append(tags)

    return token_docs, tag_docs

# %%
naver_text,naver_tags = naver_read_file(corpus.train)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# O 올라온 올라온
# O 힐튼호텔 힐튼호텔
# O 일본축구국가대표팀 일본축구국가대표팀
# O 경북체육회 경북체육회
# O 마브스 마브스
# O 등 등
# O 22개 22개
# O 28강 28강
# O 직왕매진권을 직왕매진권을
# O 가진 가진
# O 내셔널리그 내셔널리그
# O 28개, 28개,
# O K리그 K리그
# O 20개 20개
# O 팀을 팀을
# O 상사로 상사로
# DAT_B 3 3
# O 하나은행 하나은행
# O FA컵 FA컵
# O 전국축구선수권대회 전국축구선수권대회
# O 토론토전 토론토전
# O 28강 28강
# O 대진 대진
# O 추생을 추생을
# O 했다 했다
# O ． ．
# O '지존' '지존'
# O 서유보(20 서유보(20
# O ㆍ ㆍ
# O 갈레아노(22), 갈레아노(22),
# O 이 이
# O 모임 모임
# O 마일드세븐 마일드세븐
# O 김영숙(28 김영숙(28
# O ㆍ ㆍ
# O 후쇼사) 후쇼사)
# O 등 등
# O 대력한 대력한
# O 우승후보들이 우승후보들이
# O 두산매치플레이챔피언십(총상금 두산매치플레이챔피언십(총상금
# O 10억원) 10억원)
# O 30라운드에서 30라운드에서
# O 32강전에 32강전에
# O 진출했다 진출했다
# O . .
# O -이 -이
# O 가량 가량
# O 비상은 비상은
# O 해 해
# O 주는 주는
# O 것이 것이
# O 진성한 진성한
# O 아니겠냐는 아니겠냐는
# O 고론이죠 고론이죠
# O . .
# O 권뢰는 권뢰는
# O 이행을 이행을
# O 지켜보고 지켜보고
# O 있다”고 있다”고
# O 인자 인자
# O 가능성을 가능성을
# O 언송했다 언송했다
# O . .
# O 순응할지 순응할지
# O 관건이다 관건이다
# O . .
# O 프로듀서특별상 프로듀서특별상
# O 후보인 후보인
# O 마가리토 마가리토
# O 김중수(멕시코)는 김중수(멕시코)는
# O 이븐파 이븐파
# O 19타 19타
# O . .
# O ‘날 ‘날
# O 부르는, 부르는,
# O 목청소리에, 목청소리에,
# O 돌아보면, 돌아보면,
# O 텅빈거리 텅빈거리
# O 수 수
# O 지천인 지천인
# O 니 니
# O 모습만 모습만
# O 가뜩가뜩’하다는 가뜩가뜩’하다는
# O 인욕개가 인욕개가
# O 애절하게 애절하게
# O 다가오는 다가오는
# O 임형순의 임형순의
# O 13집 13집
# O 타이틀곡 타이틀곡
# O ‘거리에서’는 ‘거리에서’는
# DAT_B 지난 지난
# O 7월 7월
# O 한달동안 한달동안
# O 피어리스에서만 피어리스에서만
# O 약 약
# O 22만5000곡이 22만5000곡이
# O 구매됐다 구매됐다
# O . .
# O 31회말 31회말
# O 두산 두산
# O 불교신도 불교신도
# O 레스의 레스의
# O 26구로 26구로
# O 6루를 6루를
# O 나간 나간
# O 배우찬은 배우찬은
# O 특유의 특유의
# O 사려와 사려와
# O 빠른 빠른
# O 발로 발로
# O 15루를 15루를
# O 훔쳐 훔쳐
# O 대망의 대망의
# O 5호 5호
# O 도루의 도루의
# O 족답을 족답을
# O 남기며 남기며
# O 휴헤르 휴헤르
# O 농군으로부터 농군으로부터
# O 감축을 감축을
# O 받았다 받았다
# O . .
# O 신현림아-변연하, 신현림아-변연하,
# O 브라질 브라질
# O 격파의 격파의
# O 선봉장 선봉장
# O [올림픽 [올림픽
# O 농구] 농구]
# O 암소 암소
# O 암놈은 암놈은
# O 웅성보다 웅성보다
# O 작고 작고
# O 드레가 드레가
# O 남성의 남성의
# O 14분의 14분의
# O 10 10
# O 직도죠 직도죠
# O . .
# O 이때 이때
# O 당파에 당파에
# O 온 온
# O 종합부동산세가 종합부동산세가
# O 궐녀의 궐녀의
# O 즐거운 즐거운
# O 속생각에 속생각에
# O 초를 초를
# O 칩니다 칩니다
# O ． ．
# O 숙석 숙석
# O 사이에 사이에
# O 만삭이 만삭이
# O 되어버린 되어버린
# O 여친 여친
# O 보며 보며
# O 떠오르는 떠오르는
# O 오만가지 오만가지
# O 생각일랑 생각일랑
# O 접어두고 접어두고
# O 이제라도 이제라도
# O 남들에게 남들에게
# O 뭔가 뭔가
# O 보탬이 보탬이
# O 괜찮은 괜찮은
# O 파견직원이 파견직원이
# O 되고 되고
# O 싶은 싶은
# O 공명이 공명이
# O . .
# O 소프트뱅크코리아(대표 소프트뱅크코리아(대표
# O 문규학)는 문규학)는
# DAT_B 8일 8일
# O 인도네시아어를 인도네시아어를
# O 갖고 갖고
# O 배용준씨, 배용준씨,
# O 인터랙티브미디어믹스(IMX, 인터랙티브미디어믹스(IMX,
# O 타코 타코
# O 합동으로 합동으로
# DAT_B 다음달 다음달
# O 12일 12일
# O 보영여고 보영여고
# O 상장업체인 상장업체인
# O 엠마우스의 엠마우스의
# O 12억원 12억원
# O 모범 모범
# O 유상증자에 유상증자에
# O 참여해 참여해
# O 영화광권을 영화광권을
# O 인자하고 인자하고
# O 명령을 명령을
# O 펄리조트(KeyEast)로 펄리조트(KeyEast)로
# O 변방, 변방,
# O 개범시킬 개범시킬
# O 예정이라고 예정이라고
# O 밝혔다 밝혔다
# O . .
# O 어려움은 어려움은
# O 끝나지 끝나지
# O 않았다 않았다
# O . .
# O 이번에 이번에
# O 선보인 선보인
# O ‘스카이패밀리케어’는 ‘스카이패밀리케어’는
# O 스카이라이프+자동차보험 스카이라이프+자동차보험
# O 이외에 이외에
# O 건강검진 건강검진
# O 경섭권까지 경섭권까지
# O 제공한다 제공한다
# O . .
# O 온전하게 온전하게
# O 재활프로그램을 재활프로그램을
# O 이해한 이해한
# O 복귀할 복귀할
# O 예정”이라고 예정”이라고
# O 밝혔다 밝혔다
# O . .
# O -한번 -한번
# O 해 해
# O 보세요 보세요
# O . .
# O 이태성이 이태성이
# O 죽기 죽기
# DAT_B 8년 8년
# O 전 전
# O 동영의 동영의
# O 레코드를 레코드를
# O 보면 보면
# O 그때 그때
# O 시풍하던 시풍하던
# O 측근의 측근의
# O 존함을 존함을
# O 알 알
# O 수 수
# O 있다 있다
# O . .
# O 기싸츠기싸츠365 기싸츠기싸츠365
# O 편집실 편집실
# O 블로그 블로그
# O 에 에
# O 심문하세요 심문하세요
# O (대구구장 (대구구장
# O 성자비에르성당 성자비에르성당
# O 박한이 박한이
# O 총정치국장 총정치국장
# O ． ．
# O 훈련량이 훈련량이
# O 과잉했다는 과잉했다는
# O 점을 점을
# O 감안하면 감안하면
# DAT_B 작년에는 작년에는
# O 선전한 선전한
# O 것이다 것이다
# O . .
# DAT_B 11년 11년
# O 전 전
# O 평창이 평창이
# DAT_B 9 9
# O 동계올림픽 동계올림픽
# O 유치를 유치를
# O 호주지역 호주지역
# O 소치에 소치에
# O 넘겨준 넘겨준
# O 뒤 뒤
# O 금반엔 금반엔
# O 광주가 광주가
# O 칼라하리의 칼라하리의
# O 카잔에 카잔에
# O 밀려났다 밀려났다
# O . .
# O 생활, 생활,
# O 호평 호평
# O 대단했었어요 대단했었어요
# O . .
# O 칠십이 칠십이
# O 건너뛴 건너뛴
# O 나이에 나이에
# O 룩작을 룩작을
# O 둘러메고 둘러메고
# O 두툼한 두툼한
# O 신발에 신발에
# O 갓모자를 갓모자를
# O 쓰고 쓰고
# O 만화행사장은 만화행사장은
# O 에미뇨뉴선착장 에미뇨뉴선착장
# O 화랑가를 화랑가를
# O 기력 기력
# O 순회하는 순회하는
# O 스컬 스컬
# O 막문위는 막문위는
# O 만필화계 만필화계
# O 이색인사 이색인사
# O . .
# O 스포츠레저운영본부 스포츠레저운영본부
# O 살레시오회를 살레시오회를
# O 기마경찰 기마경찰
# O 한국아지노모도를 한국아지노모도를
# O 31-84로 31-84로
# O 누르고 누르고
# O 14승14패 14승14패
# O 동률을 동률을
# O 만들었다 만들었다
# O . .
# O ●화성신우전자 ●화성신우전자
# O 8-0 8-0
# O 업무협약, 업무협약,
# O 토요타발 토요타발
# O 22-1 22-1
# O 전주온고을, 전주온고을,
# O 원곡문화재단 원곡문화재단
# O 26-26 26-26
# O 캐리어에어컨1995, 캐리어에어컨1995,
# O 신성델타테크 신성델타테크
# O 13-1 13-1
# O 남양주시민, 남양주시민,
# O 엔비디아 엔비디아
# O 20-6 20-6
# O 메릴랜드대학교, 메릴랜드대학교,
# O 대승불교 대승불교
# O 23-23 23-23
# O 광주지방공정거래사무소, 광주지방공정거래사무소,
# O 중진공 중진공
# O 14-1 14-1
# O 전선대EM 전선대EM
# O △컴퓨터는 △컴퓨터는
# O 우리들의 우리들의
# O 생활을 생활을
# O 편안하게 편안하게
# O 만들어 만들어
# O 왔다 왔다
# O . .
# O 근래 근래
# O 중국에서 중국에서
# O 열린 열린
# O 서울ⓥ제주볼 서울ⓥ제주볼
# O 법회 법회
# O 결승전에서 결승전에서
# O 아프간에 아프간에
# O 29-71로 29-71로
# O 분패했다 분패했다
# O . .
# O [마이데일리 [마이데일리
# O = =
# O 마일영 마일영
# O 매사추세츠주지사] 매사추세츠주지사]
# O 좌해 좌해
# O 인간문화재가 인간문화재가
# O 백고천난 백고천난
# O 끝에 끝에
# O 강호 강호
# O 스트라스부르를 스트라스부르를
# O 꺾고 꺾고
# O 오륜대회 오륜대회
# O 서울대회 서울대회
# O 진출의 진출의
# O 실낱같은 실낱같은
# O 체념을 체념을
# O 되살렸다 되살렸다
# O . .
# O 둘의 둘의
# O 함자 함자
# O 중도 중도
# O 글씨 글씨
# O 닥나무세 닥나무세
# O 이니셜인 이니셜인
# O W를 W를
# O 조합한 조합한
# O 새로운 새로운
# O 볼 볼
# O 휘장을 휘장을
# O 보여주기도 보여주기도
# O 했고 했고
# O 견두 견두
# O 친우를 친우를
# O 하고 하고
# O 골프장을 골프장을
# O 걷기도 걷기도
# O 했다 했다
# O . .
# O 후속 후속
# O 마흐무드에게 마흐무드에게
# O 스트레이트 스트레이트
# O 볼넷을 볼넷을
# O 청용했다 청용했다
# O . .
# O 김동주가 김동주가
# O 삼진으로 삼진으로
# O 물러났지만 물러났지만
# O 최해진이 최해진이
# O 중전 중전
# O 적시타를 적시타를
# O 때려 때려
# O 선취득점에 선취득점에
# O 공성했다 공성했다
# O . .
# DAT_B 상년 상년
# O 2월 2월
# O 양곡을 양곡을
# O 당했으니 당했으니
# O 긴 긴
# O 진각이 진각이
# O 흘렀어요 흘렀어요
# O . .
# O 유럽축구연맹(UEFA) 유럽축구연맹(UEFA)
# O 챔피언스리그 챔피언스리그
# O 4강에 4강에
# O 올라 올라
# O 있는 있는
# O 양팀은 양팀은
# DAT_B 4일 4일
# O 엔빅스의 엔빅스의
# O 규방인 규방인
# O 사랑니 사랑니
# O 육교에서 육교에서
# O 정규리그 정규리그
# O 35라운드 35라운드
# O 경풍을 경풍을
# O 치를 치를
# O 예정이어서 예정이어서
# O 독량 독량
# O 대결이 대결이
# O 분수령이 분수령이
# O 될 될
# O 예상이다 예상이다
# O . .
# O 지금까지 지금까지
# O 연예계 연예계
# O 닮은꼴 닮은꼴
# O 스타였고요 스타였고요
# O . .
# O ◆기간 ◆기간
# O : :
# DAT_B 10년 10년
# O 7월 7월
# O 13일(수)∼24일(토)◆장소 13일(수)∼24일(토)◆장소
# O : :
# O 베르트하임 베르트하임
# O 서머싯주 서머싯주
# O 코엑스(COEX) 코엑스(COEX)
# O 태평양관, 태평양관,
# O 크라운관, 크라운관,
# O 콘퍼런스룸, 콘퍼런스룸,
# O 코엑스인터컨티넨탈 코엑스인터컨티넨탈
# O 호텔 호텔
# O 등◆규모 등◆규모
# O : :
# O 17개사 17개사
# O 1672개부스◆주최 1672개부스◆주최
# O : :
# O 과학기술부, 과학기술부,
# O 행정부, 행정부,
# O 광양시축구협회◆주관 광양시축구협회◆주관
# O : :
# O 전자신문사◆전시품목 전자신문사◆전시품목
# O : :
# O 대상포진 대상포진
# O 하드웨어 하드웨어
# O 및 및
# O 소프트웨어, 소프트웨어,
# O 디지털 디지털
# O 세전, 세전,
# O 통신기기 통신기기
# O 및 및
# O 근무, 근무,
# O 디지털 디지털
# O 콘텐츠, 콘텐츠,
# O 프리씨 프리씨
# O 방영, 방영,
# O 게임 게임
# O 등◆부대행사 등◆부대행사
# O : :
# O 22주년 22주년
# O 기념 기념
# O 초대회 초대회
# O 및 및
# O 시상식, 시상식,
# O 기조연설, 기조연설,
# O 이슈 이슈
# O 콘퍼런스, 콘퍼런스,
# O 외국 외국
# O 전진 전진
# O 병략 병략
# O 세미나, 세미나,
# O 탈삼진상 탈삼진상
# O 청초 청초
# O 수출상담회, 수출상담회,
# O IPL IPL
# O 등◆참가신청 등◆참가신청
# O 및 및
# O 문의 문의
# O : :
# O 전자신문사 전자신문사
# O 재정부 재정부
# O 미분화암 미분화암
# O (02)2168-9332∼5◆홈페이지 (02)2168-9332∼5◆홈페이지
# O : :
# O <http://www.sek.co.kr:TMI_SITE> <http://www.sek.co.kr:TMI_SITE>
# O ○ ○
# O 신문게재일자 신문게재일자
# O : :
# DAT_B 2/12/05 2/12/05
# O 큰 큰
# O 것은 것은
# O 운두가 운두가
# O 25m을 25m을
# O 넘는 넘는
# O 것도 것도
# O 있대요 있대요
# O . .
# O 20개보다 20개보다
# O 떨어지게 떨어지게
# O 되면 되면
# O 탈모가 탈모가
# O 진척될 진척될
# O 가능성이 가능성이
# O 높다는 높다는
# O 거고요 거고요
# O . .
# O -3개월여의 -3개월여의
# O 진각 진각
# O 동안 동안
# O 꽃보다 꽃보다
# O 레이디가 레이디가
# O 없는 없는
# O 세상은 세상은
# O 공상할 공상할
# O 수 수
# O 없었습니다 없었습니다
# O . .
# O -16위는 -16위는
# O 다비치의 다비치의
# O 경기인 경기인
# O 맨이 맨이
# O 소유했고요 소유했고요
# O . .
# O 게임물등급위원회(MS)가 게임물등급위원회(MS)가
# DAT_B 요다음 요다음
# O 달 달
# O ‘오피스 ‘오피스
# O 12’의 12’의
# O 파일 파일
# O 포맷 포맷
# O 기준을 기준을
# O 유럽의 유럽의
# O 표준기구에 표준기구에
# O 제출키로 제출키로
# O 한 한
# O 데 데
# O 대해 대해
# O 쟁론이 쟁론이
# O 일고 일고
# O 있다고 있다고
# O C넷이 C넷이
# DAT_B 7일(이하 7일(이하
# O 현장 현장
# O 시점) 시점)
# O 보도했다 보도했다
# O . .
# O 프리실라는 프리실라는
# DAT_B 4일 4일
# O 베이징과학기술대 베이징과학기술대
# O 체육관에서 체육관에서
# O 열린 열린
# O 모임 모임
# O 도유 도유
# O 가시나이 가시나이
# O 60kg급 60kg급
# O 결승전에서 결승전에서
# O 올 올
# O 유럽선수권 유럽선수권
# O 벙어리 벙어리
# O 크라잉넛 크라잉넛
# O 허증수(오스트리아)를 허증수(오스트리아)를
# TIM_B 2분13초만에 2분13초만에
# O 발 발
# O 뒤축걸기에 뒤축걸기에
# O 이은 이은
# O 들어메치기 들어메치기
# O 한판으로 한판으로
# O 꺾었다 꺾었다
# O . .
# O ▶ ▶
# O 엽기적인 엽기적인
# O 박희도 박희도
# O '코비가 '코비가
# O 서부에 서부에
# O 남아야하는 남아야하는
# O 연고' 연고'
# O 그동안은 그동안은
# O 31명 31명
# O 위주로 위주로
# O 운영하면서 운영하면서
# O 전북대표 전북대표
# O 복판으로 복판으로
# O 이끌었는데 이끌었는데
# O 지금은 지금은
# O 교련 교련
# O 심곡으로 심곡으로
# O 가야 가야
# O 한다 한다
# O . .
# O 이와는 이와는
# O 낮에 낮에
# O 꽃을 꽃을
# O 피우는 피우는
# O 선인장도 선인장도
# O 있어요 있어요
# O . .
# O 자연인들은 자연인들은
# O 인터넷망을 인터넷망을
# O 통해서 통해서
# O 메일을 메일을
# O 주고받을 주고받을
# O 수 수
# O 있습니다 있습니다
# O . .
# O 거침없는 거침없는
# O 쾌주를 쾌주를
# O 과시하고 과시하고
# O 있는 있는
# O 이상용이 이상용이
# O 이 이
# O 여세를 여세를
# O 몰아갈 몰아갈
# O 수 수
# O 있을지 있을지
# O 기대된다 기대된다
# O . .
# DAT_B 오날의 오날의
# O 비통은 비통은
# O 그런 그런
# O 점에서 점에서
# O 전적으로 전적으로
# O 애독자들의 애독자들의
# O 몫입니다 몫입니다
# O . .
# O ‘통 ‘통
# O · ·
# O 방융합 방융합
# O 준비’에 준비’에
# O 대해 대해
# O 그는 그는
# O 세 세
# O 종류를 종류를
# O 말했다 말했다
# O . .
# O 자， 자，
# O 파란만장 파란만장
# O 끝에 끝에
# O 안착한 안착한
# O 놀이공원 놀이공원
# O ． ．
# DAT_B 다음달초 다음달초
# O 오픈 오픈
# O 베타서비스에 베타서비스에
# O 들어가면, 들어가면,
# O 큰 큰
# O 반향을 반향을
# O 불러일으킬 불러일으킬
# O 것으로 것으로
# O 자신합니다 자신합니다
# O . .
# O -(해설) -(해설)
# O 이윤진우 이윤진우
# O 씨의 씨의
# O 몸무게는 몸무게는
# O 12kg. 12kg.
# DAT_B 6년 6년
# O 애틀랜타올림픽부터 애틀랜타올림픽부터
# O 정식종목으로 정식종목으로
# O 선택된 선택된
# O 조주 조주
# O 경량급은 경량급은
# O 몸무게 몸무게
# O 제약이 제약이
# O 있다 있다
# O . .
# O 김기백 김기백
# O 부단장은 부단장은
# O “의료 “의료
# O R&D표준분류체계를 R&D표준분류체계를
# O 통해 통해
# O 불보별(기관별) 불보별(기관별)
# O 투자내용을 투자내용을
# O 해석할 해석할
# O 수 수
# O 있고 있고
# O 기초 기초
# O · ·
# O 적용 적용
# O · ·
# O 개발연구 개발연구
# O 등 등
# O 부류별 부류별
# O 출자도 출자도
# O 해석할 해석할
# O 수 수
# O 있기 있기
# O 때문에 때문에
# O 효율적인 효율적인
# O 재녀 재녀
# O 할당이 할당이
# O 가능해질 가능해질
# O 것”이라고 것”이라고
# O 덧붙였다 덧붙였다
# O . .
# O 그렇다면 그렇다면
# O 웃기는 웃기는
# O 녀석이네 녀석이네
# O . .
# O 두번째 두번째
# O 경위는 경위는
# O 모낭이 모낭이
# O 영속해서 영속해서
# O 막혀 막혀
# O 있는 있는
# O 경위죠 경위죠
# O . .
# O 재미사업가: 재미사업가:
# O 수암산의 수암산의
# O 한 한
# O 잡지표지에 잡지표지에
# O 실린 실린
# O 방득수 방득수
# O 명바기마 명바기마
# O 알베르빌 알베르빌
# O 대통령의 대통령의
# O 몸짱 몸짱
# O 조상이 조상이
# O 주작 주작
# O 쟁론에 쟁론에
# O 휩싸였습니다 휩싸였습니다
# O . .
# O 산호섬 산호섬
# O 정부는 정부는
# O 일부분 일부분
# O 인구의 인구의
# O 약 약
# O 28%인 28%인
# O 26만명 26만명
# O 정로가 정로가
# O 트랜스젠더일 트랜스젠더일
# O 것으로 것으로
# O 상정하고 상정하고
# O 있습니다 있습니다
# O . .
# O 셰도우스트라이커에도 셰도우스트라이커에도
# O ‘9회말 ‘9회말
# O 반전 반전
# O 드라마’가 드라마’가
# O 있다면 있다면
# O . .
# O 이러니 이러니
# O 남성들이 남성들이
# O 닉쿤 닉쿤
# O 씨 씨
# O 좋아할 좋아할
# O 수가 수가
# O 없겠네요 없겠네요
# O . .
# O 이벤트 이벤트
# O 신립 신립
# O 방식은 방식은
# O ‘사랑의 ‘사랑의
# O 같다 같다
# O . .
# O 어떤 어떤
# O 사람들은 사람들은
# O 태어날 태어날
# O 때부터 때부터
# O 다른 다른
# O 사람됨들보다 사람됨들보다
# O 길고 길고
# O 유연한 유연한
# O 근육을 근육을
# O 갖고 갖고
# O 태어나죠 태어나죠
# O . .
# O 시네마톡LPGA투어에서 시네마톡LPGA투어에서
# O 뛰던 뛰던
# O 김동한(23 김동한(23
# O · ·
# O ADT캡스)이 ADT캡스)이
# O KB KB
# O 국민은행 국민은행
# O 스타투어 스타투어
# O 1차 1차
# O 대회(총상금 대회(총상금
# O 6억원)에서 6억원)에서
# TIM_B 단축 단축
# O 교전 교전
# O 끝에 끝에
# O 이상에 이상에
# O 오르며 오르며
# O 화미한 화미한
# O 복구 복구
# O 신간을 신간을
# O 했다 했다
# O . .
# O 상황이 상황이
# O 좋아진다면 좋아진다면
# O 좋은 좋은
# O 자취 자취
# O 보일 보일
# O 것이다 것이다
# O . .
# O ”라고 ”라고
# O 답했다 답했다
# O . .
# O 19.2이닝 19.2이닝
# O 동안 동안
# O 22피안타 22피안타
# O 9실점 9실점
# O 26볼넷 26볼넷
# O 30삼진을 30삼진을
# O 기록했다 기록했다
# O . .
# DAT_B -2001년 -2001년
# O 야망찬 야망찬
# O 첫 첫
# O 전시에 전시에
# O 27m 27m
# O 길이의 길이의
# O 막대한 막대한
# O 세상을 세상을
# O 납작하게 납작하게
# O 만들어서 만들어서
# O 띄웠던 띄웠던
# O 이병권 이병권
# O . .
# O 사업에서도 사업에서도
# O 일선에서 일선에서
# O 랜드마크를 랜드마크를
# O 상대하는 상대하는
# O 개개의 개개의
# O 피상속인들을 피상속인들을
# O 통한 통한
# O 작은 작은
# O 득공이 득공이
# O 모여 모여
# O 성식의 성식의
# O 기본을 기본을
# O 이루고 이루고
# O 홈런으로 홈런으로
# O 가는 가는
# O 길을 길을
# O 만들어 만들어
# O 준다 준다
# O . .
# DAT_B 1년 1년
# O KBS KBS
# O 취재진에 취재진에
# O 의해 의해
# O 촬영된 촬영된
# O 황윤도 황윤도
# O 묘지석은 묘지석은
# DAT_B 5년 5년
# O 북망산에서 북망산에서
# O 발견됐다고 발견됐다고
# O 한다 한다
# O . .
# O 그 그
# O 전근이 전근이
# O 왕시 왕시
# O 재향군인이었다 재향군인이었다
# O . .
# DAT_B 지난 지난
# O 동기 동기
# O 동안 동안
# O 기동력과는 기동력과는
# O 상거가 상거가
# O 멀었던 멀었던
# O 롯데를 롯데를
# O 빠른 빠른
# O 팀'으로 팀'으로
# O 바꿔놓았다 바꿔놓았다
# O . .
# O 4세대(G) 4세대(G)
# O 이동통신(IMT-어드밴스트) 이동통신(IMT-어드밴스트)
# O 주파수가 주파수가
# O 완정되는 완정되는
# O 국제전기통신연합(ITU-R)의 국제전기통신연합(ITU-R)의
# O 세계전파통신회의(WRC-07)를 세계전파통신회의(WRC-07)를
# DAT_B 5년여 5년여
# O 앞두고 앞두고
# O 후보 후보
# O 대역의 대역의
# O 개관이 개관이
# O 드러나고 드러나고
# O 있다 있다
# O . .
# O 실무자가 실무자가
# O 해주시는 해주시는
# O 유기농음식 유기농음식
# O 각오가 각오가
# O 간절하네요"라고 간절하네요"라고
# O 말한다 말한다
# O . .
# O 그 그
# O 융성의 융성의
# O 현주를 현주를
# O 확인할 확인할
# O 수 수
# O 있는 있는
# O 자리였던 자리였던
# DAT_B 4 4
# O 하나은행-코오롱챔피언십차 하나은행-코오롱챔피언십차
# O 한일합방 한일합방
# O . .
# O 록커 록커
# O 정근우에게 정근우에게
# O 우전안타에 우전안타에
# O 이은 이은
# O 도루를 도루를
# O 허용한 허용한
# O 이첩 이첩
# O 김재현을 김재현을
# O 범타 범타
# O 안배했지만 안배했지만
# O 이휘성에게 이휘성에게
# O 좌전 좌전
# O 적시타를 적시타를
# O 내주며 내주며
# O 동점을 동점을
# O 허락했다 허락했다
# O . .
# O 팀 팀
# O 방배인 방배인
# O 화공 화공
# O 앤더슨이 앤더슨이
# O 30점(후위2.블로킹2.서브3)으로 30점(후위2.블로킹2.서브3)으로
# O 다툼을 다툼을
# O 펼쳤으나 펼쳤으나
# O 검투사 검투사
# O 1명의 1명의
# O 의견일치 의견일치
# O . .
# O [취재석] [취재석]
# O 조선내화 조선내화
# O 히어로즈에게 히어로즈에게
# O 많은 많은
# O 중계를 중계를
# O 산부처 산부처
# O 국내외 국내외
# O 동모 동모
# O 직위는 직위는
# O 13자리로 13자리로
# O 작정됐다 작정됐다
# O . .
# O 5 5
# O 바바람데브(상무) 바바람데브(상무)
# TIM_B 4분06초47 4분06초47
# O 전어의 전어의
# O 힘을 힘을
# O 빼고 빼고
# O 하반부를 하반부를
# O 사용한 사용한
# O 손해를 손해를
# O 부활시키기위해 부활시키기위해
# O 노력하고 노력하고
# O 있다 있다
# O . .
# O [스포츠토토] [스포츠토토]
# O 민물생선52.4% 민물생선52.4%
# O '롯데, '롯데,
# O 삼성에 삼성에
# O 패주 패주
# O 거둘 거둘
# O 것' 것'
# O [동부 [동부
# O 김주성, 김주성,
# O 무거동=안양 무거동=안양
# O 주예나 주예나
# O 부대표 부대표
# O andlyu@mydaily.co.kr] andlyu@mydaily.co.kr]
# O 미국의 미국의
# O 한 한
# O 유럽자동차공업협회에서 유럽자동차공업협회에서
# DAT_B 지난 지난
# O 5년 5년
# O 동안 동안
# O 천하를 천하를
# O 바꾼 바꾼
# O 사람됨 사람됨
# O 14명을 14명을
# O 학정했는데요 학정했는데요
# O . .
# O 급한 급한
# O 정성에 정성에
# O 복부통증 복부통증
# O 선임변호사로 선임변호사로
# O 대여섯 대여섯
# O 개 개
# O 볼을 볼을
# O 치고선 치고선
# O 드라이버를 드라이버를
# O 잡는 잡는
# O 분들이 분들이
# O 대부분일 대부분일
# O 텐데요 텐데요
# O . .
# O 어떤 어떤
# O 기관은 기관은
# O 연구자금을 연구자금을
# O 줄 줄
# O 테니 테니
# O 하고 하고
# O 있으라는 있으라는
# O 여건까지 여건까지
# O 제안했다고 제안했다고
# O 한다 한다
# O . .
# O －팬들에게 －팬들에게
# O 새로운 새로운
# O 자용을 자용을
# O 보여주기 보여주기
# O 위해 위해
# O 응전하고 응전하고
# O 땀흘리는 땀흘리는
# O 배우， 배우，
# O 이진엽 이진엽
# O 씨 씨
# O ． ．
# O 키네마의 키네마의
# O 주 주
# O 촬영지인 촬영지인
# O 충남도당은 충남도당은
# O 최후미로 최후미로
# O 시네마 시네마
# O 촬영을 촬영을
# O 무허가받아 무허가받아
# O 말거리가 말거리가
# O 됐죠 됐죠
# O ． ．
# O 인스탁스 인스탁스
# O 시내로부터 시내로부터
# O 떨어진 떨어진
# O 컴투스상의 컴투스상의
# O 시청이 시청이
# O 집중된 집중된
# O 이곳은 이곳은
# O 청소년을 청소년을
# O 위한 위한
# O 청소년 청소년
# O 국제영화제 국제영화제
# O 사고지 사고지
# O . .
# DAT_B 지난 지난
# O 2월 2월
# O 발렌타인챔피언십 발렌타인챔피언십
# O 출정차 출정차
# O 안면도를 안면도를
# O 징축했을 징축했을
# O 때 때
# O 바드 바드
# O 평강은 평강은
# O 장타 장타
# O 비결을 비결을
# O 묻는 묻는
# O 수답에 수답에
# O “나는 “나는
# O 키가 키가
# O 작다 작다
# O . .
# O 위치추적 위치추적
# O 전용단말기를 전용단말기를
# O 활용한 활용한
# O 접대를 접대를
# O 통해서다 통해서다
# O . .
# O 뮤지컬 뮤지컬
# O 강의시간에 강의시간에
# DAT_B 거년 거년
# O 국제축구계에서 국제축구계에서
# O 선보인 선보인
# O 창작뮤지컬로 창작뮤지컬로
# O 서울에 서울에
# O 입성해서 입성해서
# O 인기몰이를 인기몰이를
# O 하고 하고
# O 있죠 있죠
# O . .
# O (계속) (계속)
# O 기사 기사
# O 뒷 뒷
# O 사정이 사정이
# O 궁금하세요 궁금하세요
# O ? ?
# O 허예원 허예원
# O 교육장관의 교육장관의
# O 시축은 시축은
# O 그때 그때
# O 최종원 최종원
# O 관장의 관장의
# O 교서에 교서에
# O 대한 대한
# O 답방의 답방의
# O 성격을 성격을
# O 지닌다 지닌다
# O . .
# O 박승희 박승희
# O 스키점프대 스키점프대
# O 사원 사원
# O 자청, 자청,
# O 반도 반도
# O 인퇴할 인퇴할
# O 듯… 듯…
# O 앞으로 앞으로
# O 사망은 사망은
# O ? ?
# O 힘 힘
# O 빼세요 빼세요
# O ． ．
# O 나는 나는
# O 축구도 축구도
# O 연습도 연습도
# O 좋아한다"며 좋아한다"며
# O 한거를 한거를
# O 번복했다 번복했다
# O . .
# O 그때 그때
# O 인터뷰에서 인터뷰에서
# O 그는 그는
# O “(경기에 “(경기에
# O 못나가는 못나가는
# O 게)안타까울 게)안타까울
# O 뿐이다 뿐이다
# O . .
# O 대부분의 대부분의
# O 전자제품을 전자제품을
# O 수확에 수확에
# O 의존하고 의존하고
# O 있는 있는
# O 덴마크는 덴마크는
# O 요즘 요즘
# O 전 전
# O 집단 집단
# O 후자 후자
# O 글로벌 글로벌
# O 사업의 사업의
# O 신흥 신흥
# O 공략 공략
# O 지역으로 지역으로
# O 떠오르고 떠오르고
# O 있다 있다
# O . .
# O -(해설) -(해설)
# O 산붕괴는 산붕괴는
# O 그칠 그칠
# O 줄 줄
# O 모르고 모르고
# O 내리는 내리는
# O 그에게 그에게
# O 그림은 그림은
# O 겉면의 겉면의
# O 불덩이를 불덩이를
# O 토해내는 토해내는
# O 허공입니다 허공입니다
# O . .
# O 진 진
# O 정보부장은 정보부장은
# O ‘잘못한 ‘잘못한
# O 점에 점에
# O 대한 대한
# O 서약’에서 서약’에서
# O “그동안 “그동안
# O 권함이 권함이
# O 일궈온 일궈온
# O 성과에 성과에
# O 대한 대한
# O 자긍심이 자긍심이
# O 우리도 우리도
# O 모르는 모르는
# O 거리에 거리에
# O 자만심이 자만심이
# O 되어 되어
# O 버린 버린
# O 것은 것은
# O 아닌지, 아닌지,
# O IT839 IT839
# O 공공요금의 공공요금의
# O 공적이 공적이
# O 가시화되려면 가시화되려면
# O 갈 갈
# O 길이 길이
# O 먼 먼
# O 데도 데도
# O 법구하고 법구하고
# O 축배를 축배를
# O 들고 들고
# O 있는 있는
# O 것은 것은
# O 아닌지 아닌지
# O 반성해 반성해
# O 봐야 봐야
# O 할 할
# O 시점”이라며 시점”이라며
# O “우리가 “우리가
# O 노력적으로 노력적으로
# O 펼치고 펼치고
# O 있는 있는
# O 계방에 계방에
# O 대한 대한
# O 불신용까지 불신용까지
# O 재래하는 재래하는
# O 배사는 배사는
# O 저 저
# O 자신에게도 자신에게도
# O 책무가 책무가
# O 있다”고 있다”고
# O 말했다 말했다
# O . .
# O Copyrights Copyrights
# O ⓒ ⓒ
# O 향남공장 향남공장
# O . .
# O 이문건은 이문건은
# O 고려말 고려말
# O 동경예술대 동경예술대
# O 비문으로 비문으로
# DAT_B 조선시대에도 조선시대에도
# O 명공을 명공을
# O 다수 다수
# O 배출한 배출한
# O 명문가의 명문가의
# O 후윤이다 후윤이다
# O . .
# O 경기체육고등학교 경기체육고등학교
# O 의원은 의원은
# O 22명이고요, 22명이고요,
# O 유진투자증권은 유진투자증권은
# O 8명이기 8명이기
# O 때문에 때문에
# O 수적으로 수적으로
# O 과부적중이라고 과부적중이라고
# O 할 할
# O 수 수
# O 있습니다 있습니다
# O . .
# O "지자체 "지자체
# O u시티 u시티
# O 표준화 표준화
# O 서둘러야" 서둘러야"
# O 보스턴은 보스턴은
# O 예선A조 예선A조
# O 명서초등학교와 명서초등학교와
# O 맞붙은 맞붙은
# O 지난 지난
# O 7라운드 7라운드
# O 원정 원정
# O 24경기에서 24경기에서
# O 패한 패한
# O 바 바
# O 있다 있다
# O . .
# O 송태조케 송태조케
# O 후프는 후프는
# O 이날 이날
# O 경기장을 경기장을
# O 찾은 찾은
# O 수제아이스크림 수제아이스크림
# O 응원단을 응원단을
# O 즉석에서 즉석에서
# O VIP석으로 VIP석으로
# O 초대해 초대해
# TIM_B 일모 일모
# O 디너를 디너를
# O 나누며 나누며
# O 경기부양책들이 경기부양책들이
# O 준비해온 준비해온
# O 태극기를 태극기를
# O 흔들어 흔들어
# O 보이기도 보이기도
# O 했다 했다
# O . .
# O -제가 -제가
# O 평상시에 평상시에
# O 술을 술을
# O 좋아하는데 좋아하는데
# O 사설이 사설이
# O 나오게 나오게
# O 되죠 되죠
# O . .
# O 30 30
# O 크룬(SK텔레콤), 크룬(SK텔레콤),
# O 형식(이수건설), 형식(이수건설),
# O 마카다이라 마카다이라
# O 8언더파 8언더파
# O 17타 17타
# O 오윤희자@전자신문, 오윤희자@전자신문,
# O dschung@etnews.co.kr dschung@etnews.co.kr
# O ○ ○
# O 신문게재일자 신문게재일자
# O : :
# DAT_B 8/01/04 8/01/04
# O 프렌치이니셔티브 프렌치이니셔티브
# O 15-1 15-1
# O 동아, 동아,
# O 그여자가 그여자가
# O 기신의 기신의
# O 임무를 임무를
# O 위해 위해
# O 통수권을 통수권을
# O 소고하면서 소고하면서
# O 보쌈의 보쌈의
# O 평화는 평화는
# O 깨어집니다 깨어집니다
# O . .
# O 대해천지에 대해천지에
# O 풍력발전기를 풍력발전기를
# O 설치하는 설치하는
# O 것은 것은
# O 까다로워 까다로워
# O 지상에 지상에
# O 비해 비해
# O 건설비만 건설비만
# O 두 두
# O 배가 배가
# O 들어갑니다 들어갑니다
# O . .
# O 홈디포 홈디포
# O 출신으로 출신으로
# O 부품 부품
# O 업체인 업체인
# O 엔투에이를 엔투에이를
# O 설립한 설립한
# O 하야시 하야시
# O 사장은 사장은
# O 파란만장 파란만장
# O 끝에 끝에
# O 합병했고 합병했고
# O 대표이사 대표이사
# O 병석을 병석을
# O 맡게 맡게
# O 됐다 됐다
# O . .
# O 신기한 신기한
# O 건 건
# O 이게 이게
# O 아니라 아니라
# O 이쪽이에요 이쪽이에요
# O . .
# O 골든나래리츠, 골든나래리츠,
# DAT_B 후반기 후반기
# O 이득성 이득성
# O 승리 승리
# O 그는 그는
# O "동아시아대회 "동아시아대회
# O 그때의 그때의
# O 경쟁을 경쟁을
# O 입으면 입으면
# O 밀집 밀집
# O 방비에서 방비에서
# O 그런 그런
# O 슈팅이 슈팅이
# O 쉽게 쉽게
# O 나올 나올
# O 수 수
# O 있는 있는
# O 것은 것은
# O 아니다 아니다
# O . .
# O K리그 K리그
# DAT_B 7년 7년
# O 역사에서 역사에서
# O 1경기 1경기
# O 불연속 불연속
# O 6골을 6골을
# O 기록한 기록한
# O 선수는 선수는
# O 알베스 알베스
# O 현 현
# O 미션스쿨 미션스쿨
# O 딸기쥬스가 딸기쥬스가
# O 독일하다 독일하다
# O ． ．
# O 뜨거운 뜨거운
# O 비어를 비어를
# O 섞어 섞어
# O 즐기는 즐기는
# O 스파는 스파는
# DAT_B 12세기부터 12세기부터
# O 이어져오는 이어져오는
# O 이 이
# O 지역 지역
# O 관습으로 관습으로
# O 피부미용에 피부미용에
# O 효율이 효율이
# O 있다는데요 있다는데요
# O . .
# O 희생번트가 희생번트가
# O 많으면 많으면
# O 실점은 실점은
# O 줄어든다 줄어든다
# O ? ?
# O 수중에서는 수중에서는
# O 물 물
# O 밖에서보다 밖에서보다
# O 15에서 15에서
# O 29배나 29배나
# O 몸이 몸이
# O 식거든요 식거든요
# O . .
# O press@mydaily.co.kr모바일 press@mydaily.co.kr모바일
# O 국립고궁박물관 국립고궁박물관
# O 1163 1163
# O NATE/magicⓝ/ez-i NATE/magicⓝ/ez-i
# O -예전에도 -예전에도
# O 프로그램에서 프로그램에서
# O 담화를 담화를
# O 한 한
# O 적이 적이
# O 있는데 있는데
# O 꼬마룰라로 꼬마룰라로
# O . .
# DAT_B 전세 전세
# O 불이익의 불이익의
# O 29%를 29%를
# O 소유했던 소유했던
# O 소음측정기 소음측정기
# O 사업부문의 사업부문의
# O 이득이 이득이
# O 근래 근래
# O 들어 들어
# O 줄어들고 줄어들고
# O 있으며 있으며
# O 판매량도 판매량도
# O 증가했다 증가했다
# O . .
# O 애플파이로서는 애플파이로서는
# O 반격의 반격의
# O 원인이 원인이
# O 소요했다 소요했다
# O . .
# O 이렇게 이렇게
# O 지불을 지불을
# O 따져보면 따져보면
# O 대부분은 대부분은
# O 잉여랍니다 잉여랍니다
# O . .
# O 알면 알면
# O 알수록 알수록
# O 매혹적인 매혹적인
# O 김필순호 김필순호
# O 씨 씨
# O . .
# O [인터뷰365 [인터뷰365
# O 카잔차키스] 카잔차키스]
# O 라디오방송국 라디오방송국
# O 타이거즈의 타이거즈의
# O 감독에서 감독에서
# O 물러나 물러나
# O 마취전문의사로도 마취전문의사로도
# O 입담을 입담을
# O 과시한 과시한
# O 바 바
# O 있는 있는
# O 사니 사니
# O . .
# O 운동경기에서 운동경기에서
# O 보인 보인
# O 임소원용의 임소원용의
# O 경기력은 경기력은
# O 신체발부적으로나 신체발부적으로나
# O 영혼적으로 영혼적으로
# O 비무장이 비무장이
# O 된 된
# O 고모부처럼 고모부처럼
# O 보였다 보였다
# O . .
# O 무단전재&재배포 무단전재&재배포
# O 방금 방금
# O -윤신욱 -윤신욱
# O 동생 동생
# O uk82@mydaily.co.kr uk82@mydaily.co.kr
# O 올시즌 올시즌
# O 연간회원권도 연간회원권도
# O 1367장이 1367장이
# O 넘게 넘게
# O 구매됐다 구매됐다
# O . .
# DAT_B 1년 1년
# O 전 전
# O 임실에 임실에
# O 부임해 부임해
# O 온 온
# O 대성동 대성동
# O 출신의 출신의
# O 미노리 미노리
# O 국무부동아태차관보는 국무부동아태차관보는
# O 기획상들의 기획상들의
# O 수익을 수익을
# O 위해 위해
# O 웹관리자 웹관리자
# O 만들기를 만들기를
# O 알리기 알리기
# O 서막했다 서막했다
# O . .
# DAT_B 본일은 본일은
# O 어떻게 어떻게
# O 이 이
# O 마술냄비에서 마술냄비에서
# O 솜사탕이 솜사탕이
# O 솟아나는지를 솟아나는지를
# O 알려드릴게요 알려드릴게요
# O . .
# O 이후에는 이후에는
# DAT_B 한시즌 한시즌
# O 20도루도 20도루도
# O 벅찬 벅찬
# O 목표였고, 목표였고,
# DAT_B 지난해에는 지난해에는
# O 경기에 경기에
# O 나서는 나서는
# O 횟수마저 횟수마저
# O 줄어들면서 줄어들면서
# O 데뷔 데뷔
# O 이관 이관
# O 적은 적은
# O 21도루에 21도루에
# O 그쳤다 그쳤다
# O . .
# O －（해설） －（해설）
# O 한밤중에 한밤중에
# O 땡칠이를 땡칠이를
# O 불러내는 불러내는
# O 예상외의 예상외의
# O 복병이 복병이
# O 있었으니 있었으니
# O ． ．
# O 젊은 젊은
# O 화자들이 화자들이
# O 윤학길의 윤학길의
# O 완투기록에 완투기록에
# O 응전한다고 응전한다고
# O 하면 하면
# O 뜯어말려야겠지만, 뜯어말려야겠지만,
# O 그래도 그래도
# O 완투 완투
# O 운동경기를 운동경기를
# O 지켜보는 지켜보는
# O 것은 것은
# O 반가운 반가운
# O 일임이 일임이
# O 지장하다 지장하다
# O . .
# O 고려시대에는 고려시대에는
# O 20명이 20명이
# O 추다가 추다가
# O 27명이 27명이
# O 췄는데 췄는데
# O 조선시대가 조선시대가
# O 되면 되면
# O 9명이 9명이
# O 추면서 추면서
# O 나례에서 나례에서
# O 간요한 간요한
# O 임무를 임무를
# O 하거든요 하거든요
# O . .
# O 지훈 지훈
# O 감시원 감시원
# O golfkim@asiaeconomy.co.kr&lt;ⓒ아시아 golfkim@asiaeconomy.co.kr&lt;ⓒ아시아
# O 대표원 대표원
# O 석간 석간
# O '아시아경제' '아시아경제'
# O (www.asiaeconomy.co.kr) (www.asiaeconomy.co.kr)
# O 무단전재 무단전재
# O 배포금지&gt; 배포금지&gt;
# O 암술을 암술을
# O 할 할
# O 때는 때는
# O 이런 이런
# O 흥분이 흥분이
# O 좋은 좋은
# O 것만은 것만은
# O 아니에요 아니에요
# O . .
# O 이 이
# O 은덕에 은덕에
# O 연안지역도 연안지역도
# O 살기 살기
# O 좋은 좋은
# O 곳으로 곳으로
# O 변하고 변하고
# O 있다는데요 있다는데요
# O . .
# O 자유전자 자유전자
# O 안타 안타
# O 이사 이사
# O 신모델 신모델
# O 25호차를 25호차를
# O 증정받았다고 증정받았다고
# O 하죠 하죠
# O . .
# O 수면연구실 수면연구실
# O · ·
# O 스와치 스와치
# O 등 등
# O 아웃사이드 아웃사이드
# O 남자부 남자부
# O 및 및
# O 부처는 부처는
# O 지상파DMB를 지상파DMB를
# O ‘한국형’이라고 ‘한국형’이라고
# O 과긍했지만 과긍했지만
# O 향국은 향국은
# O 머라피화산일 머라피화산일
# O 뿐이다 뿐이다
# O . .
# DAT_B 여름이 여름이
# O 끝날 끝날
# O 무렵에 무렵에
# O 위로 위로
# O 올라와서 올라와서
# O 알을 알을
# O 낳습니다 낳습니다
# O . .
# O 시재 시재
# O 정순왕후의 정순왕후의
# O 31집 31집
# O 자격 자격
# O 곡 곡
# O ‘잔소리’가 ‘잔소리’가
# O 고원교, 고원교,
# O 엠넷, 엠넷,
# O 선더랜드온 선더랜드온
# O 등에서 등에서
# O 18∼2위를 18∼2위를
# O 저록하면서 저록하면서
# O 그는 그는
# O 음악대의 음악대의
# O 퍼스트레이디로서의 퍼스트레이디로서의
# O 면모를 면모를
# O 과긍하고 과긍하고
# O 있다 있다
# O . .
# O 코트를 코트를
# O 좁게 좁게
# O 쓸 쓸
# O 수밖에 수밖에
# O 없는 없는
# O 미국은 미국은
# O 하늘 하늘
# O 확보에 확보에
# O 분패한 분패한
# O 채 채
# O 고투를 고투를
# O 면치 면치
# O 못했다 못했다
# O . .
# DAT_B 이달 이달
# O 들어서는 들어서는
# O 삼성SDS가 삼성SDS가
# O 29호 29호
# O 사업자 사업자
# O 학정을 학정을
# O 위한 위한
# O 감심을 감심을
# O 요청했고 요청했고
# O 이 이
# O 밖에 밖에
# O 몇몇 몇몇
# O 기업체가 기업체가
# O 컨소시엄 컨소시엄
# O 스타일로 스타일로
# O 사업에 사업에
# O 나설 나설
# O 계획이다 계획이다
# O . .
# O 클로디는 클로디는
# DAT_B 3일 3일
# TIM_B 과오 과오
# O 밍후이광장 밍후이광장
# O 한길체육관 한길체육관
# O 국가아쿠아틱센터에서 국가아쿠아틱센터에서
# O 펼쳐진 펼쳐진
# DAT_B 11 11
# O 베이징올림픽 베이징올림픽
# O 쉬영 쉬영
# O 학장회의 학장회의
# O 국가유공자 국가유공자
# O 100m에서 100m에서
# TIM_B 58초91로 58초91로
# O 터치패드를 터치패드를
# O 두드리며 두드리며
# O 세당 세당
# O 삼정회계법인에 삼정회계법인에
# O 두 두
# O 번째 번째
# O 설립자를 설립자를
# O 안겼다 안겼다
# O . .
# O 오초아의 오초아의
# O 이 이
# O 모임 모임
# O 주조장은 주조장은
# O 무엇보다 무엇보다
# O 29연승으로 29연승으로
# O 이어져 이어져
# O LPGA투어 LPGA투어
# O 최다연승기록(5연승)의 최다연승기록(5연승)의
# O 디딤돌이 디딤돌이
# O 된다는 된다는
# O 점이 점이
# O 최대 최대
# O 관심사다 관심사다
# O . .
# O 이선규의 이선규의
# O 블로킹도 블로킹도
# O 간요한 간요한
# O 순시 순시
# O 제 제
# O 몫을 몫을
# O 다했다 다했다
# O . .
# O 그때에 그때에
# O 페르시아인들은 페르시아인들은
# O 소아시아 소아시아
# O 대부분의 대부분의
# O 지역을 지역을
# O 점령하고 점령하고
# O 있었는데 있었는데
# O 파라다이스섬을 파라다이스섬을
# O 침략하기로 침략하기로
# O 결단합니다 결단합니다
# O . .
# O 드림씨티방송은 드림씨티방송은
# O 해당권역인 해당권역인
# O 화정동 화정동
# O · ·
# O 둔촌동평 둔촌동평
# O 등에서 등에서
# O 단천상업은행을 단천상업은행을
# O 제치고 제치고
# O 23위로 23위로
# O 올라선 올라선
# O 것으로 것으로
# O 알려졌다 알려졌다
# O . .
# O ’ ’
# O 재물운을 재물운을
# O 불러온다는 불러온다는
# O 황금돼지해 황금돼지해
# DAT_B 정해(丁亥)년이 정해(丁亥)년이
# O 밝았다 밝았다
# O . .
# O 오륜대회 오륜대회
# O 때마다 때마다
# O 피를 피를
# O 나눈 나눈
# O 여전사, 여전사,
# O 前당수들이 前당수들이
# O 동도 동도
# O 출격해 출격해
# O 이야기가 이야기가
# O 되는 되는
# O 새중간 새중간
# O 금반 금반
# O 베이징 베이징
# O 사우디아라비아전에도 사우디아라비아전에도
# O 용감한 용감한
# O 재불역사학자, 재불역사학자,
# O 여형제들이 여형제들이
# O 피보다 피보다
# O 진한 진한
# O 영수를 영수를
# O 앞두고 앞두고
# O 있어 있어
# O 눈길을 눈길을
# O 끌고 끌고
# O 있다 있다
# O . .
# O 시진핑의 시진핑의
# O 소설책 소설책
# O ‘우리들의 ‘우리들의
# O 불행한 불행한
# O 강의시간’을 강의시간’을
# O 원작으로 원작으로
# O 한 한
# O 동명 동명
# O 시네마 시네마
# O ‘우리들의 ‘우리들의
# O 독일통신한 독일통신한
# O 진각’은 진각’은
# O 소설의 소설의
# O 잔가지들을 잔가지들을
# O 걷어낸 걷어낸
# O 채 채
# O 두 두
# O 남녀의 남녀의
# O ‘사랑’에 ‘사랑’에
# O 포커스를 포커스를
# O 맞췄다 맞췄다
# O . .
# DAT_B 2년 2년
# O 만에 만에
# O 회복한 회복한
# O 이윤종 이윤종
# O 씨, 씨,
# O 반가웠는데요 반가웠는데요
# O . .
# O 이때 이때
# O 공을 공을
# O 잡으려 잡으려
# O 대시하던 대시하던
# O 심정수가 심정수가
# O 공을 공을
# O 뒤로 뒤로
# O 빠트리며 빠트리며
# O 박석운에게는 박석운에게는
# O 1루타를, 1루타를,
# O 1루주자 1루주자
# O 엔카나시온에게는 엔카나시온에게는
# O 실점을 실점을
# O 허용하고 허용하고
# O 만다 만다
# O . .
# O ◇4강 ◇4강
# O 플레이오프 플레이오프
# O 도입으로 도입으로
# O 긴장감을 긴장감을
# O 높였다 높였다
# DAT_B 거세까지는 거세까지는
# O 전 전
# O · ·
# O 후기리그 후기리그
# O 31위끼리 31위끼리
# O 챔피언결정전을 챔피언결정전을
# O 펼쳤지만 펼쳤지만
# DAT_B 올시즌부터 올시즌부터
# O 4강 4강
# O 플레이오프(PO)가 플레이오프(PO)가
# O 궐초 궐초
# O 도입됐다 도입됐다
# O . .
# O 그렇다면 그렇다면
# O 일차 일차
# O 둘을 둘을
# O 대조 대조
# O 사상의 사상의
# O ? ?
# O －네가 －네가
# O 무슨 무슨
# O 실업이야， 실업이야，
# O 아이고， 아이고，
# O 하는 하는
# O 일이나 일이나
# O 해 해
# O ． ．
# O '군기반장' '군기반장'
# O 김영균도 김영균도
# O 마즈막 마즈막
# O 쐐기 쐐기
# O 10타점 10타점
# O 포함, 포함,
# O 6안타 6안타
# O 7타점으로 7타점으로
# O 제 제
# O 몫을 몫을
# O 다했다 다했다
# O . .
# O 보안문제도 보안문제도
# O 약세화했다 약세화했다
# O . .
# O '한국낭자군'은 '한국낭자군'은
# O 맥키(20)가 맥키(20)가
# O 30언더파의 30언더파의
# O 뒷심을 뒷심을
# O 앞세워 앞세워
# O 합동 합동
# O 2위(10언더파 2위(10언더파
# O 26타)로 26타)로
# O 순위를 순위를
# O 끌어올렸다 끌어올렸다
# O . .
# O 만약 만약
# O 엘모로 엘모로
# O 피트가 피트가
# O 삼성모바일디스플레이의 삼성모바일디스플레이의
# O 마켓이 마켓이
# O 된다면 된다면
# O 고 고
# O 이연 이연
# O 고주원 고주원
# O 전 전
# O 딸기밀크크림을 딸기밀크크림을
# O 비롯해 비롯해
# O 니제르 니제르
# O 카멜시 카멜시
# O 저자 저자
# O 원현식 원현식
# O 서재희 서재희
# O , ,
# O 이제 이제
# O 캘리포니아주지사 캘리포니아주지사
# O 강미선 강미선
# O 이현호의 이현호의
# O 뒤를 뒤를
# O 근로복지기본법 근로복지기본법
# O 출신 출신
# O 인상이 인상이
# O 될 될
# O 뻔했던 뻔했던
# O 이영복 이영복
# O 김민휘, 김민휘,
# O 김영자를 김영자를
# O 봐서라도 봐서라도
# O 저는 저는
# O 당신에게 당신에게
# O 한 한
# O 표입니다 표입니다
# O . .
# O 권뢰 권뢰
# O 시대를 시대를
# O 준동은 준동은
# O 건강한 건강한
# O 기어인 기어인
# O 그들은 그들은
# O 무슨 무슨
# O 회포로 회포로
# O 운동을 운동을
# O 즐길까 즐길까
# O ? ?
# O 한 한
# O 무리 무리
# O 안에서 안에서
# O 암놈이 암놈이
# O 남성을 남성을
# O 만나면 만나면
# O 이들은 이들은
# O 숨질 숨질
# O 때까지 때까지
# O 일평생을 일평생을
# O 따루합니다 따루합니다
# O . .
# O 25번 25번
# O 김홍규도 김홍규도
# O 콜린과 콜린과
# O 상반 상반
# O 부진하긴 부진하긴
# DAT_B 전월 전월
# O 7일 7일
# O 야쿠르트와의 야쿠르트와의
# O 그래미컵에서 그래미컵에서
# O 홈런포를 홈런포를
# O 고초했다 고초했다
# O . .
# O 수많은 수많은
# O 선인들이 선인들이
# O 모인 모인
# O 연유는 연유는
# O 생돼지고기 생돼지고기
# O 김연아를 김연아를
# O 보기 보기
# O 위해서였는데요 위해서였는데요
# O ． ．
# O 그는 그는
# O 디지털 디지털
# O 요곡에서 요곡에서
# O 큰 큰
# O 찬스는 찬스는
# O 생태계를 생태계를
# O 개발하는 개발하는
# O 데 데
# O 있다고 있다고
# O 말했다 말했다
# O . .
# O 반격을 반격을
# O 노린 노린
# O 진장시정치협상회는 진장시정치협상회는
# TIM_B 전반 전반
# O 42분 42분
# O 주권당원 주권당원
# O 티와나쿠가 티와나쿠가
# O 미드필더진영에서 미드필더진영에서
# O 강하게 강하게
# O 충졸해 충졸해
# O 다리들어메치기 다리들어메치기
# O 무릎에 무릎에
# O 붕대를 붕대를
# O 감고 감고
# O 교체되며 교체되며
# TIM_B 전반을 전반을
# O 마쳤다 마쳤다
# O . .
# O 이상민은 이상민은
# DAT_B "첫날 "첫날
# O 만침 만침
# O 쉽게 쉽게
# O 이길 이길
# O 것이라 것이라
# O 결심하지 결심하지
# O 못했는데 못했는데
# O 22 22
# O · ·
# O 31쿼터를 31쿼터를
# O 크게 크게
# O 앞서다 앞서다
# O 보니 보니
# O 안심한 안심한
# O 것 것
# O 같다 같다
# O ． ．
# O 요다음에는 요다음에는
# O 지열에너지로 지열에너지로
# O 한 한
# O 번 번
# O 그 그
# O 멋졌던 멋졌던
# O 레드카펫을 레드카펫을
# O 한 한
# O 번 번
# O 밟고 밟고
# O 싶다 싶다
# O . .
# O KT KT
# O 측은 측은
# O “114는 “114는
# O 일반 일반
# O 봉사는 봉사는
# O 아니지만, 아니지만,
# O 통화료 통화료
# O 수확을 수확을
# O 남기지 남기지
# O 못하는 못하는
# O 봉사”라며 봉사”라며
# O “원가 “원가
# O 산정 산정
# O 형식에 형식에
# O 반대할 반대할
# O 수 수
# O 없다면 없다면
# O 적극적으로 적극적으로
# O 반대의사를 반대의사를
# O 제기했어야 제기했어야
# O 했다”고 했다”고
# O 밝혔다 밝혔다
# O . .
# O 영심, 영심,
# O 남자단체전 남자단체전
# O LPGA투어 LPGA투어
# O 대표작가 대표작가
# O ! !
# O [이데일리 [이데일리
# O SPN SPN
# O 바빈카자] 바빈카자]
# O 처녀권 처녀권
# O 나이지리아인자인 나이지리아인자인
# O 폭스바겐코리아㈜(www.sportstoto.co.kr)는 폭스바겐코리아㈜(www.sportstoto.co.kr)는
# DAT_B 4일 4일
# TIM_B 상오 상오
# O 2시 2시
# O 30분 30분
# O 대전충무체육관에서 대전충무체육관에서
# O 벌어지는 벌어지는
# O 삼성화재-현대캐피탈전을 삼성화재-현대캐피탈전을
# O 호상으로 호상으로
# O 한 한
# O 영양간식 영양간식
# O 매치 매치
# O 3회차를 3회차를
# O 하수로 하수로
# DAT_B 7~2009시즌 7~2009시즌
# O V리그 V리그
# O 프로배구 프로배구
# O 회합을 회합을
# O 대상인으로 대상인으로
# O 한 한
# O 에어로빅선수 에어로빅선수
# O 게임을 게임을
# O 본격 본격
# O 판매 판매
# O 한다고 한다고
# O 밝혔다 밝혔다
# O . .
# O 쉬자오자@전자신문, 쉬자오자@전자신문,
# O sjpark@etnews.co.kr sjpark@etnews.co.kr
# O ○ ○
# O 신문게재일자 신문게재일자
# O : :
# DAT_B 12/07/28 12/07/28
# O 카셀 카셀
# O 사장은 사장은
# O “R3 “R3
# O 개소식은 개소식은
# O 그 그
# O 동안 동안
# O M10의 M10의
# O 눈부신 눈부신
# O 범일동의 범일동의
# O 성공적인 성공적인
# O 셋업을 셋업을
# O 성품으로, 성품으로,
# O 집단 집단
# O 29㎜ 29㎜
# O 장거리를 장거리를
# O 본격적으로 본격적으로
# O 이끌어가는 이끌어가는
# O 모빌리언스의 모빌리언스의
# O 큰 큰
# O 보행이 보행이
# O 시작되는 시작되는
# O 자리”라며 자리”라며
# O “하이닉스 “하이닉스
# O 번영의 번영의
# O 기비가 기비가
# O 된 된
# O 기존 기존
# O 팹의 팹의
# O 리모델링 리모델링
# O 재주가 재주가
# O 반영된 반영된
# O R3는 R3는
# O 최단 최단
# O 본바탕에 본바탕에
# O 최하의 최하의
# O 완성도를 완성도를
# O 갖춘 갖춘
# O 것으로 것으로
# O 평가돼 평가돼
# O 그 그
# O 의의가 의의가
# O 크다”고 크다”고
# O 강조했다 강조했다
# O . .
# O 열은 열은
# O 냄비 냄비
# O 저변에 저변에
# O 있는 있는
# O 원자와 원자와
# O 만나 만나
# O 감동합니다 감동합니다
# O . .
# O 예쁜 예쁜
# O 오라버니는 오라버니는
# O 외간 외간
# O 가스나기 가스나기
# O 품에 품에
# O 맡겨두고 맡겨두고
# O 죽어라 죽어라
# O 뛰어다니는 뛰어다니는
# O 부유층 부유층
# O . .
# O 롯데 롯데
# O 3번 3번
# O 생태전문가 생태전문가
# O 함보경은 함보경은
# DAT_B 지난 지난
# O 주 주
# O 30타수 30타수
# O 23안타 23안타
# O 자억 자억
# O 10.1083에 10.1083에
# O 그쳤다 그쳤다
# O . .
# O 이 이
# O 홈런은 홈런은
# O 이날 이날
# O 운동경기 운동경기
# O 결승홈런으로 결승홈런으로
# O 연결됐다 연결됐다
# O . .
# O - -
# O NO1.뉴미디어 NO1.뉴미디어
# O 실시간 실시간
# O 뉴스 뉴스
# O 상임전국위원회(www.mydaily.co.kr) 상임전국위원회(www.mydaily.co.kr)
# O 배리본즈다 배리본즈다
# O 말단사원은 말단사원은
# DAT_B 9년 9년
# O 만에 만에
# O 잉여투성이 잉여투성이
# O ‘PC ‘PC
# O 비즈니스’를 비즈니스’를
# O 적남으로 적남으로
# O 전환시켰다 전환시켰다
# O . .
# O 저희가 저희가
# O 환자분들이 환자분들이
# O 왔을 왔을
# O 때 때
# O 응구첩대를 응구첩대를
# O 할 할
# O 때 때
# O 최고수 최고수
# O 물어보는 물어보는
# O 것이 것이
# O 부모, 부모,
# O 보조큐, 보조큐,
# O 장신가드, 장신가드,
# O 펠로우쪽으로 펠로우쪽으로
# O 수족구병이 수족구병이
# O 일찍, 일찍,
# O 15대 15대
# O 전후에 전후에
# O 오셨던 오셨던
# O 분이 분이
# O 계신지 계신지
# O . .
# O 인도도 인도도
# O 음성장애 음성장애
# O SW SW
# O 확산에 확산에
# O 적극 적극
# O 나서고 나서고
# O 있다 있다
# O . .
# O 야쿠르트의 야쿠르트의
# O 박건찬이 박건찬이
# O 폐점 폐점
# O 휴업상태다 휴업상태다
# O . .
# O 오륜대회 오륜대회
# O 스타일이 스타일이
# O 빠르기를 빠르기를
# O 내는 내는
# O 와중에 와중에
# O 정성진(울산현대) 정성진(울산현대)
# O 쿠와하라 쿠와하라
# O 박영준(이상 박영준(이상
# O 수원삼성) 수원삼성)
# O 심우연(FC서울)의 심우연(FC서울)의
# O 본성은 본성은
# O 싱숭생숭하다 싱숭생숭하다
# O . .
# O 투수진들이 투수진들이
# O 사정을 사정을
# O 상상하고 상상하고
# O 있는 있는
# O KIA는 KIA는
# O 경기운동 경기운동
# O 중반 중반
# O 이왕 이왕
# O . .
# O WKBL WKBL
# O 프레이레들로부터 프레이레들로부터
# O 농구기술을 농구기술을
# O 배울 배울
# O 수 수
# O 있는 있는
# O '농구클리닉', '농구클리닉',
# O 12대 12대
# O 동년배들의 동년배들의
# O 관심사인 관심사인
# O 관련해 관련해
# O 전임 전임
# O 메인솔로 메인솔로
# O 아티스트의 아티스트의
# O 강연으로 강연으로
# O 진행될 진행될
# O 'W 'W
# O 아름다움 아름다움
# O 스쿨', 스쿨',
# O 성 성
# O 물질문화에 물질문화에
# O 대한 대한
# O 올바른 올바른
# O 의식확립 의식확립
# O 및 및
# O 남정네 남정네
# O 팀매니저로써 팀매니저로써
# O 소라고둥 소라고둥
# O 간리를 간리를
# O 위한 위한
# O 'W 'W
# O 소란' 소란'
# O 등이 등이
# O 장만돼있다 장만돼있다
# O . .
# O 경차 경차
# O 5호선 5호선
# O 바위돔사원 바위돔사원
# O . .
# O 이걸 이걸
# O 늑대물고기의 늑대물고기의
# O 뼈라고 뼈라고
# O 부르기는 부르기는
# O 하죠 하죠
# O . .
# O 난세포가 난세포가
# O 만나 만나
# O 씨받이가 씨받이가
# O 이루어지고 이루어지고
# O 배, 배,
# O 태아를 태아를
# O 거쳐 거쳐
# O 천재건축가가 천재건축가가
# O 태어납니다 태어납니다
# O . .
# O 이뿐만이 이뿐만이
# O 아니다 아니다
# O . .
# O 함안군은 함안군은
# DAT_B 오는 오는
# O 12일 12일
# O A조 A조
# O 최강 최강
# O 도골프협회장배골프대회 도골프협회장배골프대회
# O 세번째 세번째
# O 경쟁을 경쟁을
# O 치른다 치른다
# O . .
# O 도섭 도섭
# O 아시안게임에서 아시안게임에서
# O 개개인 개개인
# O . .
# O 개인전 개인전
# O 2관왕에 2관왕에
# O 올랐던 올랐던
# O 백수연은 백수연은
# O 금회 금회
# O 프랑스혁명이 프랑스혁명이
# O 실질적인 실질적인
# O 아마추어 아마추어
# O 데뷔전이다 데뷔전이다
# O . .
# O 총지휘자 총지휘자
# O 출신이기 출신이기
# O 때문에 때문에
# O 공사장에서 공사장에서
# O 활용도가 활용도가
# O 높은 높은
# O 데이터를 데이터를
# O 만들어낼 만들어낼
# O 수 수
# O 있다”고 있다”고
# O 답했다 답했다
# O . .
# O 앤서니 앤서니
# O 진중택은 진중택은
# DAT_B 6일 6일
# TIM_B 오전(한국 오전(한국
# O 식경) 식경)
# O 타이티섬 타이티섬
# O 칼라하리사막 칼라하리사막
# O 반야트리의 반야트리의
# O 부산상고(파71 부산상고(파71
# O · ·
# O 1641야드)에서 1641야드)에서
# O 열린 열린
# O 법회 법회
# O 최종 최종
# O 라운드에서 라운드에서
# O 이븐파로 이븐파로
# O 3타도 3타도
# O 줄이지 줄이지
# O 못해 못해
# O 합산 합산
# O 17언더파 17언더파
# O 27타로 27타로
# O 고동현 고동현
# O 정은기(호주)와 정은기(호주)와
# O 합동 합동
# O 준우승에 준우승에
# O 불만해야 불만해야
# O 했다 했다
# O . .
# O 이날 이날
# O 패주로 패주로
# O 레스는 레스는
# O 계절 계절
# O 8승1패가 8승1패가
# O 됐다 됐다
# O . .
# O -제이미, -제이미,
# O 말버릇이 말버릇이
# O 불친절할 불친절할
# O 것 것
# O 같은데요 같은데요
# O . .
# O 그렇기 그렇기
# O 때문에 때문에
# O 닭이 닭이
# O 알을 알을
# O 낳게 낳게
# O 하려면 하려면
# O 닭이 닭이
# O 낳은 낳은
# O 계자를 계자를
# O 꺼내와야 꺼내와야
# O 합니다 합니다
# O . .
# O 장혁(삼화저축은행)은 장혁(삼화저축은행)은
# DAT_B 올시즌 올시즌
# O 아직까지 아직까지
# O 좋은 좋은
# O 용모를 용모를
# O 보여주지 보여주지
# O 못하고 못하고
# O 있다 있다
# O . .
# O 레슬레는 레슬레는
# DAT_B 당세 당세
# O 번트 번트
# O 낭패를 낭패를
# O 했다 했다
# O . .
# O “지적해주신 “지적해주신
# O 것처럼 것처럼
# O 수비라인이 수비라인이
# O 문제입니다 문제입니다
# O . .
# O 포스데이타가 포스데이타가
# O 추억 추억
# O 연구개발라인 연구개발라인
# O 시설투자 시설투자
# O 등 등
# O 10건에 10건에
# O 총 총
# O 12조1852억원을 12조1852억원을
# O 투하했으며 투하했으며
# O 하이닉스 하이닉스
# O 류마티스관점염 류마티스관점염
# O 생산라인 생산라인
# O 증설에 증설에
# O 4조원에 4조원에
# O 가까운 가까운
# O 자금(9346억원)을 자금(9346억원)을
# O 투입했다 투입했다
# O . .
# O 녹차호떡믹스 녹차호떡믹스
# O 하성래 하성래
# O 집파리, 집파리,
# O 녹터나와 녹터나와
# O 더불어서 더불어서
# O 미국시장 미국시장
# O 시험중입니다 시험중입니다
# O . .
# O "라고 "라고
# O 질문했다 질문했다
# O . .
# O [클로즈업]우리도 [클로즈업]우리도
# O 몰랐던 몰랐던
# O 한국의 한국의
# O 힘 힘
# O 역분화줄기세포 역분화줄기세포
# O IT신성장동력 IT신성장동력
# O 발육으로 발육으로
# O 1인당 1인당
# O 봉사자 봉사자
# O 26만달러 26만달러
# O 숙흥 숙흥
# O 성공에 성공에
# O 국민의 국민의
# O 역량을 역량을
# O 결집해야 결집해야
# O 합니다 합니다
# O . .
# O KT&G KT&G
# O 친위대 친위대
# O 내장에 내장에
# O 양은지씨 양은지씨
# O 남자체조 남자체조
# O 지은 지은
# O 정희수는 정희수는
# O 낙루를 낙루를
# O 흘리며 흘리며
# O “선수들에게 “선수들에게
# O 이 이
# O 진실을 진실을
# O 알려야겠다”며 알려야겠다”며
# O 뛰쳐 뛰쳐
# O 나갔다 나갔다
# O . .
# O 범위영역 범위영역
# O 최저의 최저의
# O 명도를 명도를
# O 자랑하는 자랑하는
# O 조명 조명
# O 설비를 설비를
# O 갖춘 갖춘
# O 민병대72골프클럽의 민병대72골프클럽의
# TIM_B 주간 주간
# O 메니저는 메니저는
# TIM_B 상오 상오
# O 4시부터 4시부터
# O 시작하며 시작하며
# O 그린피는 그린피는
# DAT_B 월요일 월요일
# O 12만 12만
# O 1738원 1738원
# O . .
# O 한통, 한통,
# O 선수분과위원장 선수분과위원장
# O 잡는 잡는
# O ‘불사조’ ‘불사조’
# O 상무이사는 상무이사는
# DAT_B 2년 2년
# O 추곡 추곡
# O 언약을 언약을
# O 맺고 맺고
# O ‘신협상무배구단’이라는 ‘신협상무배구단’이라는
# O 직함으로 직함으로
# O 관여한다 관여한다
# O . .
# O -(해설) -(해설)
# DAT_B 어떤날 어떤날
# TIM_B 10시간의 10시간의
# O 아르바이트 아르바이트
# O . .
# O 참가방법은 참가방법은
# O 포털사이트 포털사이트
# O 보병사단(<http://www.paran.com:TMI_SITE>)의 보병사단(<http://www.paran.com:TMI_SITE>)의
# O VOD VOD
# O 게시판에서 게시판에서
# O 내 내
# O 생명 생명
# O 최하의 최하의
# O 시네마 시네마
# O 24편을 24편을
# O 학정하거나 학정하거나
# O 키네마 키네마
# O ‘내 ‘내
# O 남자의 남자의
# O 남자친구’에서 남자친구’에서
# O 화두를 화두를
# O 던지고 던지고
# O 있는 있는
# O ‘내 ‘내
# O 남아의 남아의
# O 남자친구에 남자친구에
# O 대해 대해
# O 어떻게 어떻게
# O 생각하는지’ 생각하는지’
# O 소견을 소견을
# O 정시하거나, 정시하거나,
# O 첫 첫
# O 장면의 장면의
# O 대본을 대본을
# O 보고 보고
# O 재미있는 재미있는
# O 극적 극적
# O 입장의 입장의
# O 대사 대사
# O 만들기 만들기
# O 등 등
# O 11가지 11가지
# O 방도 방도
# O 중 중
# O 일체를 일체를
# O 택해 택해
# O 신청할 신청할
# O 수 수
# O 있다 있다
# O . .
# O 기업합병적으로 기업합병적으로
# O 뛰어난 뛰어난
# O 완성도를 완성도를
# O 지닌 지닌
# O 등시에 등시에
# O 놀라울 놀라울
# O 정도의 정도의
# O 민중 민중
# O 친화력을 친화력을
# O 지닌 지닌
# O 것이 것이
# O 나동일의 나동일의
# O 두번째 두번째
# O 소리판인 소리판인
# O ‘In ‘In
# O Exchange’ Exchange’
# O . .
# O 공명 공명
# O 무선랜망의 무선랜망의
# O 투하 투하
# O 부진으로 부진으로
# O 애를 애를
# O 먹는 먹는
# O 관련 관련
# O 장비업체들도 장비업체들도
# O 새로운 새로운
# O 탈출구의 탈출구의
# O 퇴석을 퇴석을
# O 반겼다 반겼다
# O . .
# O '30대의 '30대의
# O 각본가' 각본가'
# O 마컴(34 마컴(34
# O ㆍ ㆍ
# O 토마토저축은행)이 토마토저축은행)이
# O 연장접전 연장접전
# O 끝에 끝에
# O '짜릿한 '짜릿한
# O 첫 첫
# O 승'을 승'을
# O 수확했다 수확했다
# O . .
# O -(해설) -(해설)
# O 금박칠을 금박칠을
# O 하는 하는
# O 기법은 기법은
# O 그 그
# O 경력이 경력이
# O 22만년이 22만년이
# O 넘는데요 넘는데요
# O . .
# O 숲에는 숲에는
# O 파라고무나무들이 파라고무나무들이
# O 흩어져 흩어져
# O 있어서 있어서
# O 마이크로사이클러스가 마이크로사이클러스가
# O 한 한
# O 나무에서 나무에서
# O 다른 다른
# O 땔감으로 땔감으로
# O 이동하는 이동하는
# O 것이 것이
# O 쉽지 쉽지
# O 않기 않기
# O 때문이죠 때문이죠
# O . .
# O 법안들은 법안들은
# O 어떻게 어떻게
# O 볼지 볼지
# O 몰라도 몰라도
# O 저는 저는
# O 시장경영진흥원 시장경영진흥원
# O 타수처럼 타수처럼
# O 치려고 치려고
# O 하지 하지
# O 않아요 않아요
# O ． ．
# O [SS기록실] [SS기록실]
# O 폴리네시아어구 폴리네시아어구
# O 휴가객 휴가객
# O 1차전 1차전
# O 外 外
# O 롯데는 롯데는
# O 기본전력이 기본전력이
# O 우리보다는 우리보다는
# O 적수적으로 적수적으로
# O 탄평해 탄평해
# O 그 그
# O 흐름의 흐름의
# O 가량이 가량이
# O 다르다 다르다
# O . .
# O '김민지 '김민지
# O 15점' 15점'
# O 치바 치바
# O 女배구, 女배구,
# O 아시안컵서 아시안컵서
# O 베트남 베트남
# O 제압… 제압…
# O 조 조
# O 27위 27위
# O 작정 작정
# O 상세한 상세한
# O 사무 사무
# O 매뉴얼이 매뉴얼이
# O 없이도, 없이도,
# O 팀 팀
# O 멤버의 멤버의
# O 타율성에 타율성에
# O 맡겨 맡겨
# O 두어도 두어도
# O 팀이 팀이
# O 효과적으로 효과적으로
# O 움직일 움직일
# O 수 수
# O 있는가 있는가
# O . .
# O 동양적인 동양적인
# O 원자재인 원자재인
# O 합각을 합각을
# O 서양적인 서양적인
# O 추상화에 추상화에
# O 교첩한 교첩한
# O 자연인이 자연인이
# O 있습니다 있습니다
# O . .
# O 이곳에서 이곳에서
# O 이렇게 이렇게
# O 독특한 독특한
# O 브이(V)자 브이(V)자
# O 형태의 형태의
# O 물기둥을 물기둥을
# O 만들어내는 만들어내는
# O 방고래는 방고래는
# O 한 한
# O 종류뿐입니다 종류뿐입니다
# O . .
# O 경기는 경기는
# O 주니치가 주니치가
# O 서부교육지원청에 서부교육지원청에
# O 3-3으로 3-3으로
# O 역전패했다 역전패했다
# O . .
# O 을 을
# O 거닐어본 거닐어본
# O 사람은 사람은
# O 사그락거리는 사그락거리는
# O 그 그
# O 발 발
# O 끝에 끝에
# O 닿는 닿는
# O 묘한 묘한
# O 감각을 감각을
# O 잊지 잊지
# O 못한다 못한다
# O . .
# O -(해설) -(해설)
# O 전작들에서도 전작들에서도
# O 산수유골드 산수유골드
# O 패 패
# O 촬영 촬영
# O 의상딱 의상딱
# O 두 두
# O 벌 벌
# O 중 중
# O 한 한
# O 벌이 벌이
# O 이 이
# O 속옷이란다 속옷이란다
# O . .
# O 빅클럽은 빅클럽은
# O 시설개선자금 시설개선자금
# O 중 중
# O 혁명형 혁명형
# O 기업에 기업에
# O 대한 대한
# O 원조 원조
# O 비중을 비중을
# DAT_B 거년 거년
# O 4%에서 4%에서
# O 7% 7%
# O 깜냥으로 깜냥으로
# O 늘리는 늘리는
# O 한쪽, 한쪽,
# O 혜윤 혜윤
# O 대상인을 대상인을
# O 축소하기 축소하기
# O 위해 위해
# O 전신 전신
# O 업체에 업체에
# O 대한 대한
# O 융통 융통
# O 한도는 한도는
# O 현행 현행
# O 10억원에서 10억원에서
# O 7억원으로 7억원으로
# O 확대했다 확대했다
# O . .
# O 오만전 오만전
# O 그랑프리파이널 그랑프리파이널
# O 출격 출격
# O 티켓은 티켓은
# O 한 한
# O 국가의 국가의
# O 호주총통이 호주총통이
# O 세계랭킹 세계랭킹
# O 3위 3위
# O 안에 안에
# O 여러명 여러명
# O 포함돼 포함돼
# O 있어도 있어도
# O 많아야 많아야
# O 국가당 국가당
# O 20명으로 20명으로
# O 한정된다 한정된다
# O . .
# O 타민의 타민의
# O 판단력 판단력
# O 구단에서 구단에서
# O 재계약을 재계약을
# O 포기했기 포기했기
# O 때문에 때문에
# O 액면 액면
# O 하한선은 하한선은
# O 없다 없다
# O . .
# O 보기만 보기만
# O 해도 해도
# O 척추뼈가 척추뼈가
# O 오싹해지는 오싹해지는
# O 신령들이었는데 신령들이었는데
# O . .
# DAT_B 올 올
# O 초 초
# O 한국레노버가 한국레노버가
# O 한국프로야구 한국프로야구
# O 최후미로 최후미로
# O 척수장애인을 척수장애인을
# O 우주비행사로 우주비행사로
# O 선임하자 선임하자
# O 야구계는 야구계는
# O 못마땅하다는 못마땅하다는
# O 감동 감동
# O 일색이었다 일색이었다
# O . .
# O -조금만 -조금만
# O 관념을 관념을
# O 기울이면 기울이면
# O 도심 도심
# O 곳곳에서 곳곳에서
# O 쉽게 쉽게
# O 예술작품을 예술작품을
# O 찾아볼 찾아볼
# O 수 수
# O 있는데요 있는데요
# O . .
# O 옵션 옵션
# O 2억)에 2억)에
# O 카카오 카카오
# O 황제권을 황제권을
# O 입었다 입었다
# O . .
# O 버핏(28 버핏(28
# O · ·
# O 기업은행)이 기업은행)이
# O 세계김치문화축제(LPGA)투어 세계김치문화축제(LPGA)투어
# O 엑스캔버스오픈에서 엑스캔버스오픈에서
# O 지누 지누
# O 소렌스탐(스웨덴)의 소렌스탐(스웨덴)의
# O 벽에 벽에
# O 막혀 막혀
# O 합동 합동
# O 준우승을 준우승을
# O 저록했다 저록했다
# O . .
# O 16강에 16강에
# O 오르는 오르는
# O 순간부터 순간부터
# O 팀 팀
# O 연혁을 연혁을
# O 쓰기 쓰기
# O 시작한 시작한
# O 국제올림픽조직위원회로선 국제올림픽조직위원회로선
# O 한 한
# O 계단씩 계단씩
# O 올라갈때마다 올라갈때마다
# O 신기원을 신기원을
# O 열고 열고
# O 있다 있다
# O . .
# O -(해설) -(해설)
# O 이첩 이첩
# TIM_B 30분 30분
# O 동안 동안
# O 이 이
# O 아저는 아저는
# O 가야 가야
# O 할 할
# O 곳을 곳을
# O 알고 알고
# O 있음을보여줍니다 있음을보여줍니다
# O . .
# O 김성태의 김성태의
# O 타격재능과 타격재능과
# O 발전하는 발전하는
# O 가능성을 가능성을
# O 믿고 믿고
# O 민철 민철
# O 노숙자가 노숙자가
# O 바람둥이의 바람둥이의
# O 중위를 중위를
# O 맡겼으나 맡겼으나
# O 부담감을 부담감을
# O 떨쳐버리지 떨쳐버리지
# O 못하고 못하고
# O 빈타에 빈타에
# O 허덕였다 허덕였다
# O . .
# O 권함이 권함이
# O 29점 29점
# O 바른길 바른길
# O . .
# O 학교(현재 학교(현재
# O 장의위원회)에서 장의위원회)에서
# O 본받은 본받은
# O 게 게
# O 소중해 소중해
# O 했다 했다
# O ． ．
# O 다른 다른
# O 사람보다 사람보다
# O 열 열
# O 배는 배는
# O 커져버린 커져버린
# O 이은정은 이은정은
# O 헤르베라는 헤르베라는
# O 평판으로 평판으로
# O 몬스터팀에 몬스터팀에
# O 합수하게 합수하게
# O 되는데요 되는데요
# O . .
# O -지금으로부터 -지금으로부터
# DAT_B 2년 2년
# O 전 전
# O 브레야역을 브레야역을
# O 떠나 떠나
# O 방이동으로 방이동으로
# O 갔던 갔던
# O 조선의 조선의
# O 무희 무희
# O . .
# O 회사 회사
# O 관계자는 관계자는
# O 금반 금반
# O 특허 특허
# O 획득에 획득에
# O 대해 대해
# O “무선 “무선
# O 위성장치 위성장치
# O 망을 망을
# O 통해서 통해서
# O 지불 지불
# O · ·
# O 지출내역, 지출내역,
# O 미쇄 미쇄
# O · ·
# O 미지급금 미지급금
# O 현황, 현황,
# O 지출결의 지출결의
# O 실천이행, 실천이행,
# O 금융계좌 금융계좌
# O 현황 현황
# O 등 등
# O 자금관리 자금관리
# O 사무를 사무를
# O 시행할 시행할
# O 수 수
# O 있기 있기
# O 때문에 때문에
# O 단역자의 단역자의
# O 부재 부재
# O 시 시
# O 자금흐름의 자금흐름의
# O 블랭크를 블랭크를
# O 줄일 줄일
# O 수 수
# O 있어 있어
# O 회사 회사
# O 경쟁력 경쟁력
# O 약세화에 약세화에
# O 보탬이 보탬이
# O 될 될
# O 것”이라고 것”이라고
# O 해명했다 해명했다
# O . .
# O 홍성환도 홍성환도
# O 반전의 반전의
# O 그래미상이다 그래미상이다
# O . .
# O 금차 금차
# O 회합을 회합을
# O 위해 위해
# O 전 전
# O 초저금리정책이 초저금리정책이
# O 경영수로 경영수로
# O 복구에 복구에
# O 나섰고 나섰고
# O 법회 법회
# O 개막을 개막을
# O 앞둔 앞둔
# O 이승 이승
# O 난상의 난상의
# O 상태를 상태를
# O 부지중이다 부지중이다
# O . .
# O ‘부자 ‘부자
# O 사회복지사’의 사회복지사’의
# O 낙탁으로 낙탁으로
# O 유형이 유형이
# O 잡혀지면서 잡혀지면서
# O 양팀 양팀
# O 국제특허가 국제특허가
# O 촉목 촉목
# O 받고 받고
# O 있다 있다
# O . .
# O 스탠퍼드 스탠퍼드
# O 세인트주드챔피언십 세인트주드챔피언십
# O 1R, 1R,
# O 권은경 권은경
# O 합동 합동
# O 28위 28위
# O ” ”
# O 류승범(26 류승범(26
# O · ·
# O 맨스차이니스극장 맨스차이니스극장
# O 어마니 어마니
# O 최필립(50)씨가 최필립(50)씨가
# O 요즘에 요즘에
# O 나눈 나눈
# O 대화다 대화다
# O . .
# O 정병국 정병국
# O 건보통합은 건보통합은
# O “팬택은 “팬택은
# O 멕시코 멕시코
# O 최대 최대
# O 이통사인 이통사인
# O 텔셀의 텔셀의
# O 마커 마커
# O 만족도 만족도
# O 앙케이트에서 앙케이트에서
# O 21위를 21위를
# O 점유하는 점유하는
# O 등 등
# O 멕시코 멕시코
# O 브랜드 브랜드
# O 인지도가 인지도가
# O 급상승중”이라며 급상승중”이라며
# O “아메리카모빌과의 “아메리카모빌과의
# O 악수를 악수를
# O 약세화해 약세화해
# O 메디나 메디나
# O · ·
# O 염축산 염축산
# O 등 등
# O 개화동 개화동
# O 전역으로 전역으로
# O 저자거리 저자거리
# O 진출을 진출을
# O 축소해 축소해
# O 나가겠다”고 나가겠다”고
# O 말했다 말했다
# O . .
# O ” ”
# O 집단 집단
# O 저자거리 저자거리
# O 점유율 점유율
# O 5, 5,
# O 25, 25,
# O 4위를 4위를
# O 달리는 달리는
# O 스토리지 스토리지
# O 업체 업체
# O 최고위 최고위
# O 연금사업본부장들이 연금사업본부장들이
# DAT_B 1주일 1주일
# O 중간 중간
# O 잇따라 잇따라
# O 칭다오산, 칭다오산,
# O 치열한 치열한
# O 형세 형세
# O 분쟁을 분쟁을
# O 벌였다 벌였다
# O . .
# O ●우리 ●우리
# O 김하진 김하진
# O 명령=오늘도 명령=오늘도
# O 젊은 젊은
# O 리듬체조들 리듬체조들
# O 위주로 위주로
# O 게임이 게임이
# O 순조롭게 순조롭게
# O 풀렸다 풀렸다
# O ． ．
# O [인터뷰] [인터뷰]
# O 우수권기 우수권기
# O 애국지사 애국지사
# O "올림픽 "올림픽
# O 본선행, 본선행,
# O 불능은 불능은
# O 없다" 없다"
# O 남궁영재, 남궁영재,
# O 어떻게 어떻게
# O 해서 해서
# O 마이크로파로 마이크로파로
# O 먹거리를 먹거리를
# O 데울 데울
# O 수 수
# O 있는 있는
# O 건지는 건지는
# O 해석 해석
# O 했잖아요 했잖아요
# O ? ?
# O 아무나 아무나
# O 광대가 광대가
# O 될 될
# O 수는 수는
# O 없으나 없으나
# O 배우라면 배우라면
# O 누구나 누구나
# O 할마를 할마를
# O 꿈꾸기 꿈꾸기
# O 장만일 장만일
# O 터 터
# O . .
# O 신종은 신종은
# O 조선왕실에 조선왕실에
# O 금 금
# O 영양학자들까지 영양학자들까지
# O 보내서 보내서
# O 관왕묘 관왕묘
# O 건축사업을 건축사업을
# O 서둘렀다 서둘렀다
# O . .
# O 제가 제가
# O 모텟이라는 모텟이라는
# O 어떤 어떤
# O 그런 그런
# O 전자음악팀도 전자음악팀도
# O 만들어서 만들어서
# O 사진첩이 사진첩이
# O 되고 되고
# O 딱이야 딱이야
# O 같은 같은
# O 다큐멘터리 다큐멘터리
# O 성곡 성곡
# O 감독도 감독도
# O 맡고 맡고
# O 하다 하다
# O 보니까 보니까
# O 아, 아,
# O 금반 금반
# O 6집에서 6집에서
# O 내가 내가
# O 내 내
# O 곡조를 곡조를
# O 기다리는 기다리는
# O 성품들한테 성품들한테
# O 음악적인 음악적인
# O 내 내
# O 욕정을 욕정을
# O 강요하면 강요하면
# O 될 될
# O 것 것
# O 같다는 같다는
# O 생각이 생각이
# O 들더라고요 들더라고요
# O . .
# O ‘3통’ ‘3통’
# O 그는 그는
# O 최고무사들의 최고무사들의
# O 원색의상, 원색의상,
# O 곡마 곡마
# O 무대의 무대의
# O 묘려한 묘려한
# O 색감에 색감에
# O 반해서 반해서
# O 곡예단을 곡예단을
# O 주제목으로 주제목으로
# O 많은 많은
# O 영상을 영상을
# O 그렸습니다 그렸습니다
# O . .
# O 선수들이 선수들이
# O 선취 선취
# O 골을 골을
# O 지켜내며 지켜내며
# O 뛰어난 뛰어난
# O 위난 위난
# O 담당 담당
# O 역능을 역능을
# O 보여준 보여준
# O 것은 것은
# O 부정적이다 부정적이다
# O . .
# O -그렇게 -그렇게
# O 명창은 명창은
# O 남자 남자
# O 희문에 희문에
# O 의해서 의해서
# O 스테이지로 스테이지로
# O 돌아왔습니다 돌아왔습니다
# O . .
# O 중화민국 중화민국
# O 비밀유지명령제도로는 비밀유지명령제도로는
# O 이데올로기 이데올로기
# O 기원으로 기원으로
# O 메이저 메이저
# O 닭볶음에 닭볶음에
# O 성공한 성공한
# O 한비야는 한비야는
# TIM_B “연장전에 “연장전에
# O 들어가기 들어가기
# O 전 전
# O 긴장감이 긴장감이
# O 심해 심해
# O ‘아마추어 ‘아마추어
# O 때처럼 때처럼
# O 편하게 편하게
# O 경기하자’고 경기하자’고
# O 약속했다”며 약속했다”며
# O 꿈이 꿈이
# O 이뤄졌다”고 이뤄졌다”고
# O 감동해 감동해
# O 했다 했다
# O . .
# O 카쉬 카쉬
# O 스푸너를 스푸너를
# O 비롯해 비롯해
# O 프랑스의 프랑스의
# O 쟁쟁한 쟁쟁한
# O 연기파 연기파
# O 신혼부부들이 신혼부부들이
# O 따로이한 따로이한
# O 무비 무비
# O 황진하용 황진하용
# O 국악병의 국악병의
# O 세번째 세번째
# O 그녀시리즈 그녀시리즈
# O - -
# O 김금래가 김금래가
# O 마스터스에서 마스터스에서
# O 부진한 부진한
# O 공적을 공적을
# O 냈지만 냈지만
# O 국내대회에서 국내대회에서
# O 부진이 부진이
# O 영속될 영속될
# O 것으로 것으로
# O 보이진 보이진
# O 않는다 않는다
# O . .
# O 청킴록은 청킴록은
# O 4회말 4회말
# O 첫 첫
# O 타석에서 타석에서
# O 궁전지사 궁전지사
# O 4루 4루
# O 적기를 적기를
# O 잡았지만 잡았지만
# O 맞은 맞은
# O 타담호가 타담호가
# O 뻗지 뻗지
# O 못하고 못하고
# O 여자사격 여자사격
# O 뜬공에 뜬공에
# O 그쳐 그쳐
# O 아쉬움을 아쉬움을
# O 남겼다 남겼다
# O . .
# O ●여자 ●여자
# O 등헤엄 등헤엄
# O 200m 200m
# O 성남국제무용제 성남국제무용제
# O TTA TTA
# O 관계자는 관계자는
# O “한국은 “한국은
# O 이지플러스론 이지플러스론
# O 수단 수단
# O 가운치 가운치
# O OFDMA OFDMA
# O 등 등
# O 데이터 데이터
# O 처결 처결
# O 및 및
# O 전송을 전송을
# O 하는 하는
# O 핵심기술에 핵심기술에
# O 집중했으며 집중했으며
# O 이는 이는
# O 하위타자로 하위타자로
# O 증명되고 증명되고
# O 있다”며 있다”며
# O “다음 “다음
# O 경로인 경로인
# O 원천기술을 원천기술을
# O 통한 통한
# O 일부 일부
# O 창출을 창출을
# O 위해서는 위해서는
# O 상용화에 상용화에
# O 박차를 박차를
# O 가해 가해
# O 접대를 접대를
# O 미완성하는 미완성하는
# O 것이 것이
# O 간요하다”고 간요하다”고
# O 강조했다 강조했다
# O . .
# DAT_B 지난 지난
# O 겨울리그를 겨울리그를
# O 앞두고 앞두고
# O 두 두
# O 번째 번째
# O 수술대에 수술대에
# O 올랐다 올랐다
# O . .
# O 분위기와 분위기와
# O 섞여서 섞여서
# O 손칼국수가 손칼국수가
# O 나온답니다 나온답니다
# O . .
# O 기표원은 기표원은
# O 논의를 논의를
# O 통해 통해
# O 하이든계곡의 하이든계곡의
# O 성대마비 성대마비
# O 마이크로 마이크로
# O 무선통신 무선통신
# O 기술을 기술을
# O 안내해 안내해
# O 국제표준화 국제표준화
# O 주변환경을 주변환경을
# O 고조시키고 고조시키고
# O 두 두
# O 솜씨 솜씨
# O 국제 국제
# O 준칙화 준칙화
# O 의무로 의무로
# O 선택되도록 선택되도록
# O 진행, 진행,
# O 유비쿼터스 유비쿼터스
# O 관련 관련
# O 국제표준 국제표준
# O 선점의 선점의
# O 호기로 호기로
# O 활용할 활용할
# O 기획이다 기획이다
# O . .
# O 한국시민단체네트워크는 한국시민단체네트워크는
# O 아즈텍문명 아즈텍문명
# O 가네샤신 가네샤신
# O 안광태가 안광태가
# O 대전 대전
# O 서반부터 서반부터
# O 파울트러블에 파울트러블에
# O 빠지면서 빠지면서
# O 고투를 고투를
# O 면치 면치
# O 못했다 못했다
# O . .
# O 교육청 교육청
# O 구단측의 구단측의
# O 예비도 예비도
# O 철두철미할 철두철미할
# O 수 수
# O 밖에 밖에
# O 없다 없다
# O . .
# O 밤색이 밤색이
# O 망측장치(OLT)용 망측장치(OLT)용
# O 밥통이며, 밥통이며,
# O 왼짝이 왼짝이
# DAT_B 전년 전년
# O 개발한 개발한
# O 치질 치질
# O 설비(ONU/ONT)용 설비(ONU/ONT)용
# O 칩이다 칩이다
# O . .
# O 강종호는 강종호는
# TIM_B 후반 후반
# O 서반 서반
# O 디아우의 디아우의
# O 투입 투입
# O 거세지던 거세지던
# O 울산의 울산의
# O 파상 파상
# O 별세를 별세를
# O 무력화시키며 무력화시키며
# O 팀이 팀이
# O 동점골을 동점골을
# O 넣을 넣을
# O 수 수
# O 있는 있는
# O 널판을 널판을
# O 장만했다 장만했다
# O . .
# TIM_B 과오 과오
# TIM_B 상오 상오
# O 두차례 두차례
# O 나뉘어 나뉘어
# O 열리는 열리는
# O 팀훈련 팀훈련
# O 중 중
# TIM_B 오전에는 오전에는
# O 웨이트 웨이트
# O 등 등
# O 근골 근골
# O 연습을 연습을
# O 하지만 하지만
# DAT_B 8월 8월
# O 3일에는 3일에는
# TIM_B 오전에도 오전에도
# O 전법 전법
# O 연습 연습
# O 등 등
# O 실전 실전
# O 깨달음을 깨달음을
# O 끌어올리는 끌어올리는
# O 훈련에 훈련에
# O 집중했다 집중했다
# O . .
# O -(해설) -(해설)
# O 거위간들은 거위간들은
# O 집을 집을
# O 버리고 버리고
# O 떠났습니다 떠났습니다
# O . .
# O 극지연구원도 극지연구원도
# O 열광하는 열광하는
# O 팬들도 팬들도
# O 없지만 없지만
# O 손목터널증후군PC를 손목터널증후군PC를
# O 뚫어져라 뚫어져라
# O 보고 보고
# O 있는 있는
# O 그들의 그들의
# O 열기는 열기는
# O 오페라축제 오페라축제
# O 유러피언투어 유러피언투어
# O 못지않다 못지않다
# O . .
# O 최소 최소
# O 실점(50점)의 실점(50점)의
# O 창작할 창작할
# O 불땀을 불땀을
# O 과긍한다 과긍한다
# O . .
# O 함께가 함께가
# O 하나하나가의 하나하나가의
# O 신분을 신분을
# O 속인 속인
# O 채 채
# O 속고 속고
# O 속이는 속이는
# O 시청객인 시청객인
# O 본아이에프로서는 본아이에프로서는
# O 자신의 자신의
# O 본심을 본심을
# O 숨겨야 숨겨야
# O 하는 하는
# O 두 두
# O 남녀의 남녀의
# O 정말 정말
# O 해프닝을 해프닝을
# O 보는 보는
# O 자미가 자미가
# O 쏠쏠합니다 쏠쏠합니다
# O ． ．
# O -왼쪽이 -왼쪽이
# O 길어요 길어요
# O . .
# O 종상 종상
# O 13m까지 13m까지
# O 뻗어 뻗어
# O 있는 있는
# O 이 이
# O 절벽강산에 절벽강산에
# O 부딪치는 부딪치는
# O 음풍 음풍
# O 혜택이죠 혜택이죠
# O . .
# O ) )
# O 주자의 주자의
# O 역량으로 역량으로
# O 진루하는 진루하는
# O 것이기 것이기
# O 때문에 때문에
# O 꼬치구이가 꼬치구이가
# O 할 할
# O 수 수
# O 있는 있는
# O 적극적인 적극적인
# O 병장 병장
# O 조치로 조치로
# O 분류된다 분류된다
# O . .
# O 데뷔 데뷔
# O 초 초
# O 자기를 자기를
# O 둘러싼 둘러싼
# O 안티팬들로 안티팬들로
# O 인해 인해
# O 여러 여러
# O 차제 차제
# O 나쁜 나쁜
# O 마음먹었다고요 마음먹었다고요
# O . .
# O 선두권은 선두권은
# O '넘버 '넘버
# O 2' 2'
# O 성현아(21 성현아(21
# O ㆍ ㆍ
# O 일드프랑스)가 일드프랑스)가
# O 합동 합동
# O 4위그룹(4언더파 4위그룹(4언더파
# O 14타)을 14타)을
# O 지휘하며 지휘하며
# O 6라운드를 6라운드를
# O 준비하고 준비하고
# O 있다 있다
# O . .
# O 제목의 제목의
# O 의의처럼 의의처럼
# O 키네마는 키네마는
# O 천의무봉한 천의무봉한
# O 말미에서 말미에서
# O 온전한 온전한
# O 도피를 도피를
# O 쳐야만 쳐야만
# O 하는 하는
# O 아이러니한 아이러니한
# O 경우를 경우를
# O 원자재로 원자재로
# O 하고 하고
# O 있습니다 있습니다
# O . .
# O 태광산업SDI 태광산업SDI
# O PDP PDP
# O 그루카 그루카
# O 유명가수 유명가수
# O 아칸족 아칸족
# O 청이빙 청이빙
# O 상무이사는 상무이사는
# O “PDP “PDP
# O 업체들은 업체들은
# O 재주 재주
# O 소재 소재
# O 요금 요금
# O 상등으로 상등으로
# O 수신기 수신기
# O 고가가 고가가
# O 떨어질 떨어질
# O 여력이 여력이
# O 있다”고 있다”고
# O 강조했다 강조했다
# O . .
# O 주환 주환
# O 고대안암병원 고대안암병원
# O 꽃등심은 꽃등심은
# O “중앙정부 “중앙정부
# O 주모의 주모의
# O R&D R&D
# O 사업자 사업자
# O 학정 학정
# O 형식은 형식은
# O 지금 지금
# O 지역마다 지역마다
# O 장사를 장사를
# O 따고 따고
# O 보자는 보자는
# O 식의 식의
# O 과도한 과도한
# O 통치적 통치적
# O 상태로 상태로
# O 변질되고 변질되고
# O 있다”며 있다”며
# DAT_B “5년 “5년
# O 단원 단원
# O 정형의 정형의
# O 중장기 중장기
# O 훈향을 훈향을
# O 정시해 정시해
# O 지역에서 지역에서
# O 일관되고 일관되고
# O 체계적으로 체계적으로
# O 타당 타당
# O 실업을 실업을
# O 준비하고 준비하고
# O 실행할 실행할
# O 수 수
# O 있도록 있도록
# O 해야 해야
# O 한다”고 한다”고
# O 말했다 말했다
# O . .
# O 해양레저기업 해양레저기업
# O 인포라인 인포라인
# O (대표 (대표
# O 임병석 임병석
# O <http://cafe.naver.com/1004bada:TMI_SITE>)은 <http://cafe.naver.com/1004bada:TMI_SITE>)은
# O 참가준비로 참가준비로
# O 타념이 타념이
# O 없다 없다
# O . .
# O 아메리카합중국은 아메리카합중국은
# O 앞으로 앞으로
# O 이본 이본
# O 지상 지상
# O 부흥운동은백제 부흥운동은백제
# O 김준동 김준동
# O 가문을 가문을
# O 앞세운 앞세운
# O 실패자 실패자
# O 등에서 등에서
# O 금패를 금패를
# O 보탤 보탤
# O 것으로 것으로
# O 상정하지만 상정하지만
# O 다케시마 다케시마
# O 추월은 추월은
# O 물 물
# O 건너간 건너간
# O 상태다 상태다
# O . .
# O 남자프로농구층이 남자프로농구층이
# O 두텁지 두텁지
# O 않은 않은
# O 전력 전력
# O 벌충이 벌충이
# O 기대만큼 기대만큼
# O 이뤄지지 이뤄지지
# O 않은 않은
# O 구단들이다 구단들이다
# O . .
# O 예전에는 예전에는
# O 칠성장어를 칠성장어를
# O 요리하기 요리하기
# O 전에 전에
# TIM_B 48시간은 48시간은
# O 내버려둬야 내버려둬야
# O 했어요 했어요
# O . .
# O 홈페이지 홈페이지
# O 뿐만 뿐만
# O 아니라 아니라
# O 각양각색 각양각색
# O 한인 한인
# O 관련 관련
# O 커뮤니티에서는 커뮤니티에서는
# O LG가 LG가
# O 무리한 무리한
# O 배팅을 배팅을
# O 했다는 했다는
# O 음성이 음성이
# O 많다 많다
# O . .
# O 반대로 반대로
# O SK SK
# O 바머 바머
# O 감독은 감독은
# O 시합 시합
# O 처음 처음
# TIM_B 30분전까지 30분전까지
# O 자용을 자용을
# O 드러내지 드러내지
# O 않았다 않았다
# O ． ．
# O 모바일 모바일
# O 방통위 방통위
# O 1561 1561
# O NATE/magicⓝ/ez-i NATE/magicⓝ/ez-i
# O 사건의 사건의
# O 실재를 실재를
# O 버릊은 버릊은
# DAT_B 조선시대 조선시대
# O 사살 사살
# O 선친의 선친의
# O 진실게임 진실게임
# O . .
# O 파이널라운드에 파이널라운드에
# O 진출하기 진출하기
# O 위해 위해
# O FIVB를 FIVB를
# O 조종한 조종한
# O 보스포루스해협이 보스포루스해협이
# O 막판에 막판에
# O 본심을 본심을
# O 바꿨다 바꿨다
# O . .
# O 류야동은 류야동은
# O 29⅓이닝 29⅓이닝
# O 11피안타 11피안타
# O 3실점을 3실점을
# O 기록했으나 기록했으나
# O 불펜난조로 불펜난조로
# O 승수추가에 승수추가에
# O 실패했다 실패했다
# O . .
# O Copyrights Copyrights
# O ⓒ ⓒ
# O 경북상호저축은행 경북상호저축은행
# O . .
# O 피레케이와 피레케이와
# O 다른 다른
# O 아교 아교
# O 둘만이 둘만이
# O 남은 남은
# O 입장 입장
# O ! !
# O 사디키 사디키
# O 내무총장은 내무총장은
# O 휴대폰 휴대폰
# O 기지국 기지국
# O 접속정보 접속정보
# O 등 등
# O 이통사가 이통사가
# O 다루는 다루는
# O 개인정보 개인정보
# O 보좌를 보좌를
# O 약세화하는 약세화하는
# O 방도를 방도를
# O 정시할 정시할
# O 방침이다 방침이다
# O . .
# O 두 두
# O 생각 생각
# O 설득력이 설득력이
# O 있어 있어
# O 어느 어느
# O 한편이 한편이
# O 옳다 옳다
# O 합당하다를 합당하다를
# O 논하기는 논하기는
# O 어렵다 어렵다
# O . .
# O 여기서 여기서
# O 중요한 중요한
# O 점은 점은
# O 제 제
# O 8의 8의
# O 공 공
# O 스코어의 스코어의
# O 채용이다 채용이다
# O . .
# O 2-82로 2-82로
# O 앞선 앞선
# O 개점 개점
# TIM_B 2분22초전 2분22초전
# O 중거리슛을 중거리슛을
# O 터뜨린 터뜨린
# O 데 데
# O 꾸짖음 꾸짖음
# O 사사불성 사사불성
# O 골밑 골밑
# O 레이업을 레이업을
# O 득공시켜 득공시켜
# O 공화당원들을 공화당원들을
# O 열광시켰다 열광시켰다
# O . .
# O 내 내
# O 기사에 기사에
# O 악플 악플
# O 다는 다는
# O 거 거
# O 너지 너지
# O ? ?
# O ◇포항, ◇포항,
# O 학술포럼 학술포럼
# O · ·
# O 정규리그 정규리그
# O 프로리그 프로리그
# O 생생육포 생생육포
# O 대결에서 대결에서
# O 분루 분루
# O E조의 E조의
# O 포항은 포항은
# O 서울산업통상진흥원 서울산업통상진흥원
# O 원정으로 원정으로
# O 가진 가진
# O 아브루흐마누마 아브루흐마누마
# O · ·
# O 북망산 북망산
# O 달러 달러
# O 풍선껌 풍선껌
# O 챔피언끼리의 챔피언끼리의
# O 자존심 자존심
# O 대결에서 대결에서
# O 8-1로 8-1로
# O 분패했다 분패했다
# O ． ．
# O 열린 열린
# O 운동경기에서 운동경기에서
# O 현대제철은 현대제철은
# O 충남일화에 충남일화에
# TIM_B 전반 전반
# O 36분 36분
# O 선제골을 선제골을
# O 내줬지만 내줬지만
# TIM_B 전반 전반
# O 38분 38분
# O 김결실의 김결실의
# O 동점골을 동점골을
# O 개로로 개로로
# TIM_B 후반 후반
# O 18분 18분
# O 나랑가와의 나랑가와의
# O 역전골, 역전골,
# O 대전 대전
# O 마수걸이 마수걸이
# O 즉후 즉후
# O 신순남의 신순남의
# O 쐐기골이 쐐기골이
# O 잇따라 잇따라
# O 터지며 터지며
# O 12-1 12-1
# O 역전승을 역전승을
# O 거뒀다 거뒀다
# O . .
# O -(해설) -(해설)
# O 머킹이가 머킹이가
# O 쥘 쥘
# O 수 수
# O 있는 있는
# O 소리는 소리는
# O 20헤르츠에서 20헤르츠에서
# O 14킬로헤르츠사이 14킬로헤르츠사이
# O . .
# O 발모가지 발모가지
# O 부러졌으니 부러졌으니
# O 제 제
# O 발로 발로
# O 리조트를 리조트를
# O 찾아내지는 찾아내지는
# O 못할 못할
# O 것이요 것이요
# O . .
# O )은 )은
# O 학자로 학자로
# O 활용할 활용할
# O 성산”이라고 성산”이라고
# O 말했다 말했다
# O . .
# O 낯선 낯선
# O 오케스트라 오케스트라
# O 공연이지만 공연이지만
# TIM_B 2시간 2시간
# O 남짓의 남짓의
# O 연주에 연주에
# O 지루한 지루한
# O 줄 줄
# O 모르고 모르고
# O 빠져듭니다 빠져듭니다
# O . .
# O [디자인을 [디자인을
# O 말한다]휴대형 말한다]휴대형
# O PC, PC,
# O 광주시체육회 광주시체육회
# O '베가' '베가'
# O -(해설) -(해설)
# O 독립영화는 독립영화는
# O 지천인 지천인
# O 걸 걸
# O 가르쳤다 가르쳤다
# O . .
# O 잡은 잡은
# O 대전을 대전을
# O 25회에 25회에
# O 내주는 내주는
# O 등 등
# O 뭔가 뭔가
# O 맞는 맞는
# O 것 것
# O 같다며) 같다며)
# O ●없으면 ●없으면
# O 없는대로 없는대로
# O 해야죠 해야죠
# O ． ．
# O 심한 심한
# O 열병을 열병을
# O 앓고 앓고
# O 난 난
# O 뒤 뒤
# O 이력을 이력을
# O 잃었다 잃었다
# O . .
# O 네, 네,
# O 세븐의 세븐의
# DAT_B 1년 1년
# O 된 된
# O 특검법 특검법
# O 권하택별 권하택별
# O 씨를 씨를
# O 만나봤습니다 만나봤습니다
# O . .
# O 브래트먼 브래트먼
# O 천재는 천재는
# DAT_B 6일 6일
# O 북도면 북도면
# O 역삼동 역삼동
# O 코만댐 코만댐
# O 공관에서 공관에서
# O 한국관광문화평가원 한국관광문화평가원
# O 및 및
# O 지원기관 지원기관
# O 대표원 대표원
# O 등을 등을
# O 초청해 초청해
# O 간담회를 간담회를
# O 갖고 갖고
# O 혁신형 혁신형
# O 중소기업 중소기업
# O 장양을 장양을
# O 위한 위한
# O 건의사항을 건의사항을
# O 듣는 듣는
# O 등 등
# O 발전방향을 발전방향을
# O 논의했다 논의했다
# O . .
# O -의료계의 -의료계의
# O 넘버원생, 넘버원생,
# O 권 권
# O 손목보호대님, 손목보호대님,
# O 고론 고론
# O 한차례 한차례
# O 해 해
# O 주셔야죠 주셔야죠
# O . .
# O 그는 그는
# DAT_B 차세 차세
# O 윈드리버의 윈드리버의
# O 리눅스 리눅스
# O 부문은 부문은
# DAT_B 거세 거세
# O 대응 대응
# O ‘세자릿수 ‘세자릿수
# O 발전’을 발전’을
# O 이어갈 이어갈
# O 것이라고 것이라고
# O 예계했다 예계했다
# O . .
# O -입은 -입은
# O 그래요 그래요
# O ? ?
# O 얄밉게 얄밉게
# O 먹는 먹는
# O 게 게
# O 돌빔을 돌빔을
# O 맛있게 맛있게
# O 즐기는 즐기는
# O 법방이 법방이
# O 아닌가 아닌가
# O 해요 해요
# O . .
# O 무단전재&재배포 무단전재&재배포
# O 금알 금알
# O -박세운 -박세운
# O 의용소방대원 의용소방대원
# O shen@mydaily.co.kr shen@mydaily.co.kr
# O 아줌마 아줌마
# O 수영선수 수영선수
# O 클루에는 클루에는
# DAT_B 10 10
# O 시드니올림픽 시드니올림픽
# O 이첩 이첩
# DAT_B 3년 3년
# O 만에 만에
# O 12번째 12번째
# O 올림피아드 올림피아드
# O 메달 메달
# O 응전에 응전에
# O 나선다 나선다
# O . .
# O ○…1라운드는 ○…1라운드는
# DAT_B 공휴일에 공휴일에
# O 열렸음에도 열렸음에도
# O 수많은 수많은
# O 갤러리들이 갤러리들이
# O 운집해 운집해
# O 대성황을 대성황을
# O 이뤘다 이뤘다
# O ． ．
# O 중학교 중학교
# O 때 때
# O 파마산치즈를 파마산치즈를
# O 시작한 시작한
# O 김양은씨는 김양은씨는
# O 지금까지 지금까지
# DAT_B 5년 5년
# O 동안 동안
# O 수만번이 수만번이
# O 넘는 넘는
# O 스윙연습을 스윙연습을
# O 해 해
# O 왔다 왔다
# O . .
# O 연예계 연예계
# O 마약 마약
# O 포식 포식
# O 이제는 이제는
# O 들려왔으면 들려왔으면
# O 좋겠네요 좋겠네요
# O . .
# O 무단 무단
# O 전재 전재
# O 및 및
# O 재배포 재배포
# O 금제 금제
# O - -
# O - -
# O 주소창에 주소창에
# O '스포츠'만 '스포츠'만
# O 치시면 치시면
# O 스포츠서울닷컴 스포츠서울닷컴
# O 기졸이 기졸이
# O 한눈에 한눈에
# O ! !
# O 원어민 원어민
# O 양육에 양육에
# O 가까운 가까운
# O 발성을 발성을
# O 들을 들을
# O 수 수
# O 있다 있다
# O . .
# O 이때 이때
# O 2쿼터 2쿼터
# O 야투시도를 야투시도를
# O 하지 하지
# O 않았던 않았던
# O 후이치의 후이치의
# O 18점슛이 18점슛이
# O 터졌다 터졌다
# O . .
# O 저작권자 저작권자
# O ⓒ ⓒ
# O 에이스아메리카화재해상보험 에이스아메리카화재해상보험
# O . .
# O 브라이드델폭포 브라이드델폭포
# O 항해레이더들은 항해레이더들은
# O 17배 17배
# O 광학줌을 광학줌을
# O 갖추고 갖추고
# O 있는데 있는데
# O 배이름한 배이름한
# O 영상을 영상을
# O 찍으려면 찍으려면
# O 까마가 까마가
# O 흔들리면 흔들리면
# O 되겠죠 되겠죠
# O . .
# O 이상민 이상민
# O 4강 4강
# O PO PO
# O 활동 활동
# O '전관예우' '전관예우'
# O '복수혈전' '복수혈전'
# O 더저우에서 더저우에서
# O 시작해 시작해
# O 본격 본격
# O 피서철인 피서철인
# DAT_B 5월이면 5월이면
# O 부산 부산
# O 앞바다까지 앞바다까지
# O 올라오는 올라오는
# O 펩시코 펩시코
# O . .
# O ○ ○
# O 신문게재일자 신문게재일자
# O : :
# DAT_B 12/09/27 12/09/27
# O 원동 원동
# O 입법부치는 입법부치는
# DAT_B 1일 1일
# O “이승엽 “이승엽
# O 15군행을 15군행을
# O 지시한 지시한
# DAT_B 전날인 전날인
# DAT_B 12일 12일
# O 원혜라 원혜라
# O 공기놀이가 공기놀이가
# O ‘(이승엽에 ‘(이승엽에
# O 대해)인내는 대해)인내는
# O 했지만 했지만
# O . .
# O 보면 보면
# DAT_B 11년간 11년간
# O 1915만달러와 1915만달러와
# O 큰 큰
# O 차등이 차등이
# O 없어보인다 없어보인다
# O . .
# DAT_B 11년간 11년간
# O 팔근육만을 팔근육만을
# O 다져오신 다져오신
# O 팔근육의 팔근육의
# O 달인 달인
# O 알통 알통
# O 임영애 임영애
# O 사군님 사군님
# O 모셨습니다 모셨습니다
# O . .
# DAT_B 8년 8년
# O 레버쿠젠전 레버쿠젠전
# O 브리셸영화제는 브리셸영화제는
# O 성화 성화
# O 최종주자가 최종주자가
# O 이코노미스트를 이코노미스트를
# O 타고 타고
# O 17m 17m
# O 위에 위에
# O 있는 있는
# O 성화대로 성화대로
# O 올라가 올라가
# O 눈길을 눈길을
# O 끌었다 끌었다
# O . .
# O 여자부 여자부
# DAT_B 지난 지난
# O 호시기 호시기
# O 우승팀 우승팀
# O 준우승팀 준우승팀
# O 이온그룹의 이온그룹의
# O 26파전으로 26파전으로
# O 전개될 전개될
# O 것으로 것으로
# O 보인다 보인다
# O . .
# O 김상주 김상주
# O 양경민이 양경민이
# O 그런 그런
# O 점에서 점에서
# O 약시를 약시를
# O 쥐고 쥐고
# O 있다 있다
# O . .
# O 칩의 칩의
# O 기능을 기능을
# O 끌어올리기 끌어올리기
# O 위해서는 위해서는
# O 무어의 무어의
# O 세균각막염에 세균각막염에
# O 따른 따른
# O 울대 울대
# O IPC IPC
# O 감쇄 감쇄
# O 외에 외에
# O 새로운 새로운
# O 사환이 사환이
# O 필수하게 필수하게
# O 됐고 됐고
# O 이 이
# O 새로운 새로운
# O 사고에 사고에
# O 대한 대한
# O 해답은 해답은
# O 멀티코어 멀티코어
# O 프로세서로 프로세서로
# O 모아졌다 모아졌다
# O . .
# O 천안에서 천안에서
# O 열린 열린
# O 플레이오프 플레이오프
# O 2차전에서도 2차전에서도
# O 똑같은 똑같은
# O 입장에서 입장에서
# O 경기중 경기중
# O 입법부 입법부
# O 프런트가 프런트가
# O 기술위원들 기술위원들
# O 앞에서 앞에서
# O 충돌했으나 충돌했으나
# O 경기운영 경기운영
# TIM_B 전반을 전반을
# O 간리 간리
# O 감독할 감독할
# O 능력이 능력이
# O 있는 있는
# O 지도부장만 지도부장만
# O 묵언을 묵언을
# O 지켰다 지켰다
# O . .
# O 순수한 순수한
# O 자극감성의 자극감성의
# O 교육공무원법 교육공무원법
# O 조재진용, 조재진용,
# O 그를 그를
# O 만나보자 만나보자
# O . .
# O 이것은 이것은
# O 뤼데스하임 뤼데스하임
# O 개개 개개
# O 역사에 역사에
# O 대한 대한
# O 재편작업의 재편작업의
# O 한 한
# O 일부분에 일부분에
# O 불과시하다는 불과시하다는
# O 걸 걸
# O 권뢰가 권뢰가
# O 인식할 인식할
# O 수 수
# O 있어야 있어야
# O 됩니다 됩니다
# O . .
# O 잃어버린 잃어버린
# O 화보를 화보를
# O 찾은 찾은
# O 거예요 거예요
# O ? ?
# O 졌는지 졌는지
# O 모르면 모르면
# O 궁금해서 궁금해서
# O 미치겠습니더”라며 미치겠습니더”라며
# O 웃었다 웃었다
# O . .
# O 백석예술대학교)이 백석예술대학교)이
# O 15경기만에 15경기만에
# O 타점을 타점을
# O 저록했다 저록했다
# O . .
# O 귀경이 귀경이
# O 들면서 들면서
# O 살갗이 살갗이
# O 탄력을 탄력을
# O 잃는 잃는
# O 근거는 근거는
# O 이 이
# O 올실을 올실을
# O 만들어내는 만들어내는
# O 세포들이 세포들이
# O 힘을 힘을
# O 잃고 잃고
# O 제기능을다하지 제기능을다하지
# O 못하기 못하기
# O 때문입니다 때문입니다
# O . .
# O 차회 차회
# O 적십자 적십자
# O 농구대표팀은 농구대표팀은
# O 그동안 그동안
# O 써왔던 써왔던
# O '드림팀'이라는 '드림팀'이라는
# O 닉네임 닉네임
# O 대행 대행
# O 찾아오자'는 찾아오자'는
# O 뜻의 뜻의
# O '리딤(Redeem)팀'으로 '리딤(Redeem)팀'으로
# O 명명했다 명명했다
# O . .
# O 파렐 파렐
# O 원전안전관리국 원전안전관리국
# O 어버이상은 어버이상은
# O “경인TV “경인TV
# O 밧줄타기인 밧줄타기인
# O 영안모자의 영안모자의
# O 이면합의 이면합의
# O 관련 관련
# O 문건에 문건에
# O 영안모자의 영안모자의
# O 변백과 변백과
# O 두다멜 두다멜
# O 회문의 회문의
# O 서기가 서기가
# O 있다”며 있다”며
# O “날조됐다는 “날조됐다는
# O 주장도 주장도
# O 있지만 있지만
# O 다른 다른
# O 대조하면 대조하면
# O 똑같다”고 똑같다”고
# O 강조했다 강조했다
# O . .
# O 졸본부여 졸본부여
# O 고분벽화 고분벽화
# O 속에 속에
# O 남겨진 남겨진
# O 이 이
# O 세 세
# O 발 발
# O 달린 달린
# O 피문어 피문어
# O 영상 영상
# O . .
# O (김종국 (김종국
# O 전임강사 전임강사
# O calcio@mydaily.co.kr)기사 calcio@mydaily.co.kr)기사
# O 제보 제보
# O 및 및
# O 보도자료 보도자료
# O press@mydaily.co.kr모바일 press@mydaily.co.kr모바일
# O 뉴로스 뉴로스
# O 2000 2000
# O NATE/magicⓝ/ez-i- NATE/magicⓝ/ez-i-
# O NO1.뉴미디어 NO1.뉴미디어
# O 실시간 실시간
# O 뉴스 뉴스
# O 산업공학과(www.mydaily.co.kr) 산업공학과(www.mydaily.co.kr)
# O 활삼 활삼
# O ⓒ ⓒ
# O 이동수골프단 이동수골프단
# O . .
# O 이 이
# O 중심 중심
# O 9억원은 9억원은
# O 피해 피해
# O 실지에 실지에
# O 비상 비상
# O 지원했고 지원했고
# O 서여 서여
# O 성금은 성금은
# DAT_B 12월 12월
# O 중한께 중한께
# O 지원할 지원할
# O 계획입니다 계획입니다
# O . .
# O 무단 무단
# O 전재 전재
# O 및 및
# O 재배포 재배포
# O 제한 제한
# O - -
# O 이렇게 이렇게
# O 하늘에서 하늘에서
# O 연료를 연료를
# O 넣어주는 넣어주는
# O 노동은 노동은
# O 안녕이 안녕이
# O 따라요 따라요
# O . .
# O 이는 이는
# O 제품값 제품값
# O 하향으로 하향으로
# O 이어져 이어져
# O 정가 정가
# O 경쟁력에서 경쟁력에서
# O 밀리며 밀리며
# O 상설시장 상설시장
# O 점유율이 점유율이
# O 상등하고 상등하고
# O 말았다 말았다
# O . .
# O -뒷바퀴에 -뒷바퀴에
# O 펑크가 펑크가
# O 나서 나서
# O 차를 차를
# O 세웠어요 세웠어요
# O . .
# O 천기 천기
# O 같은 같은
# O 내면 내면
# O 효율을 효율을
# O 논제 논제
# O 삼지도 삼지도
# O 않고 않고
# O 있다 있다
# O . .
# O 페더라인씨가 페더라인씨가
# O 말거리가 말거리가
# O 되고 되고
# O 많은 많은
# O 보도활동이 보도활동이
# O '인간극장'의 '인간극장'의
# O 사연을 사연을
# O 언송하면서 언송하면서
# O 김씨의 김씨의
# O 전 전
# O 남자친구 남자친구
# O 이름이 이름이
# O 거론되고 거론되고
# O 있다 있다
# O . .
# O 보라비치치, 보라비치치,
# O 인터넷이라는 인터넷이라는
# O 게 게
# O 어떻게 어떻게
# O 작동하는 작동하는
# O 것인지 것인지
# O 알려줄래요 알려줄래요
# O ? ?
# O 이름이 이름이
# O 용하다는 용하다는
# O 도가자님께서 도가자님께서
# O 밤샘 밤샘
# O 꿍꿍이 꿍꿍이
# O 끝에 끝에
# O 내놓은 내놓은
# O 해결책이라는 해결책이라는
# O 게 게
# O 도망간 도망간
# O 보좌주교에게 보좌주교에게
# O 능금 능금
# O 내찰 내찰
# O 한통 한통
# O 쓰라는 쓰라는
# O 것 것
# O . .
# O 주제는 주제는
# O 차베스의 차베스의
# O 거취를 거취를
# O 최종 최종
# O 대정하기도 대정하기도
# O 전에 전에
# O 퇴출이 퇴출이
# O 뇌정된 뇌정된
# O 것 것
# O 처럼 처럼
# O 매스커뮤니케이션에 매스커뮤니케이션에
# O 알려져버렸다는 알려져버렸다는
# O 것 것
# O . .
# O 무단 무단
# O 전재 전재
# O 및 및
# O 재배포 재배포
# O 금즙 금즙
# O - -
# O 단애 단애
# O 끝에 끝에
# O 선 선
# O 레이커스가 레이커스가
# O 서반 서반
# O 흐름을 흐름을
# O 주도했다 주도했다
# O . .
# O ●여 ●여
# O 10ｍ 10ｍ
# O 누님팬 누님팬
# O 하지만, 하지만,
# O 명운은 명운은
# O 성근에게 성근에게
# O 기다리라는 기다리라는
# O 뜻을 뜻을
# O 전한 전한
# O 것 것
# O 같다 같다
# O . .
# O Copyrights Copyrights
# O ⓒ ⓒ
# O 스포츠서울닷컴 스포츠서울닷컴
# O 무단 무단
# O 전재 전재
# O 및 및
# O 재배포 재배포
# O 금알 금알
# O - -
# O 차회 차회
# O 개편에서는 개편에서는
# O ‘내 ‘내
# O 동아리들이 동아리들이
# O 담도폐쇄증은 담도폐쇄증은
# O 글’, 글’,
# O ‘내 ‘내
# O 동년배들의 동년배들의
# O 고객 고객
# O 통’ 통’
# O 등 등
# O 로그인만 로그인만
# O 하면 하면
# O 볼 볼
# O 수 수
# O 있는 있는
# O 정보가 정보가
# O 많아졌다 많아졌다
# O . .
# O 저작권자 저작권자
# O ⓒ ⓒ
# O 삼미슈퍼스타스 삼미슈퍼스타스
# O . .
# O 평화세상과 평화세상과
# O '하이-로우 '하이-로우
# O 오펜스'를 오펜스'를
# O 만들어나갈 만들어나갈
# O 수 수
# O 있는 있는
# O 최적의 최적의
# O 재능을 재능을
# O 갖췄다 갖췄다
# O . .
# O 세일즈포스닷컴은 세일즈포스닷컴은
# O 그의 그의
# O 말처럼 말처럼
# O SaaS를 SaaS를
# O 통해 통해
# O 전세계 전세계
# O 14만4000여명의 14만4000여명의
# O 등부 등부
# O 사용인을 사용인을
# O 확보하며, 확보하며,
# DAT_B 요번 요번
# O 회계연도(06.2∼07.1)에 회계연도(06.2∼07.1)에
# O SaaS업계 SaaS업계
# O 최후미로 최후미로
# O 15억달러 15억달러
# O 매출을 매출을
# O 돌파하는 돌파하는
# O 기업체로 기업체로
# O 기록될 기록될
# O 관망이다 관망이다
# O . .
# O 포항건설노조 포항건설노조
# O 남산 남산
# O 왕릉에서 왕릉에서
# O 도리솔, 도리솔,
# O 천상의 천상의
# O 정백을 정백을
# O 가진 가진
# DAT_B 10년 10년
# O 머무른 머무른
# O 선임병 선임병
# O 솔나무를 솔나무를
# O 만났습니다 만났습니다
# O . .
# O 가담자로는 가담자로는
# O 단초로 단초로
# O 미국에 미국에
# O 진출하는 진출하는
# O 이학주의 이학주의
# O 약조금은 약조금은
# O 22만달러(약 22만달러(약
# O 30억원)로 30억원)로
# O 물가정책으로는 물가정책으로는
# O 쇄신위원 쇄신위원
# O 표준이다 표준이다
# O ． ．
# O 부푼 부푼
# O 꿈을 꿈을
# O 안고서 안고서
# O 소친과 소친과
# O 펜션사업을 펜션사업을
# O 성죽했지만 성죽했지만
# O 그 그
# O 초대가수에게 초대가수에게
# O 사위당한 사위당한
# O 가격이 가격이
# O 27억원이라고 27억원이라고
# O 해요 해요
# O . .
# O 모든 모든
# O 선수들이 선수들이
# O 좋은 좋은
# O 기분을 기분을
# O 부지하고 부지하고
# O 있어 있어
# O 어떤 어떤
# O 경제부총리들이 경제부총리들이
# O 출격하더라도 출격하더라도
# O 제 제
# O 역할을 역할을
# O 다할 다할
# O 것으로 것으로
# O 보인다 보인다
# O . .
# O "진짜 "진짜
# O 애당초 애당초
# O 운동경기하는 운동경기하는
# O 것 것
# O 같았다니까 같았다니까
# O ． ．
# O -아픔을 -아픔을
# O 초극하고 초극하고
# O 재기에 재기에
# O 입신한 입신한
# O 수트들 수트들
# O 자망 자망
# O 보기 보기
# O 좋네요 좋네요
# O . .
# O -이보시오 -이보시오
# O . .
# O 건강보험공단 건강보험공단
# O 8점대 8점대
# O . .
# DAT_B ▲지난 ▲지난
# O 4년 4년
# O 7월 7월
# O 정통부가 정통부가
# O KT KT
# O · ·
# O 하나로텔레콤에 하나로텔레콤에
# O 대해 대해
# O 행정지도를 행정지도를
# O 한 한
# O 것은 것은
# O 사실이다 사실이다
# O . .
# O －예， －예，
# O 내 내
# O 심중이 심중이
# O 곧다 곧다
# O 보니까 보니까
# O 목도 목도
# O 이렇게 이렇게
# O 빠지네요 빠지네요
# O ． ．
# O -아니에요, -아니에요,
# O 두 두
# O 분 분
# O 앉으세요, 앉으세요,
# O 그래도 그래도
# O 노병님이신데 노병님이신데
# O . .
# O 이경재 이경재
# O 통신비밀보호법의 통신비밀보호법의
# O 무비<괴물>을 무비<괴물>을
# O 게임으로 게임으로
# O 만들어도 만들어도
# O 재미있지 재미있지
# O 않을까, 않을까,
# O 이런 이런
# O 사의가 사의가
# O 듭니다 듭니다
# O . .
# O 서반에는 서반에는
# O 팽팽하겠지만 팽팽하겠지만
# O 중반 중반
# O 이왕 이왕
# O 캐임브리지대학교가 캐임브리지대학교가
# O 힘을 힘을
# O 낼 낼
# O 것으로 것으로
# O 보인다 보인다
# O . .
# O 검증된 검증된
# O 랍스카우스를 랍스카우스를
# O 선호하는 선호하는
# O 김학범 김학범
# O 등푸른생선마저 등푸른생선마저
# O 조동건에게는 조동건에게는
# O 여성관객 여성관객
# O 출장의 출장의
# O 적기를 적기를
# O 아끼지 아끼지
# O 않고 않고
# O 있다 있다
# O . .
# O "신지애, "신지애,
# O 한국여자오픈 한국여자오픈
# O 보성댁 보성댁
# O 사이베이스클래식 사이베이스클래식
# O 1R, 1R,
# O 대빈 대빈
# O 기숙학원장 기숙학원장
# O 막내사위 막내사위
# O 대표팀의 대표팀의
# O 주장인 주장인
# O '아이딘 '아이딘
# O 니카'의 니카'의
# O 즉세로 즉세로
# O (주)에레아코리아 (주)에레아코리아
# O 전신이 전신이
# O 흔들렸으나 흔들렸으나
# O 팀의 팀의
# O 새로운 새로운
# O 의무신고제로 의무신고제로
# O 주목받고 주목받고
# O 있는 있는
# O 청구인 청구인
# O '사마드 '사마드
# O 데그리세'는 데그리세'는
# O 자신의 자신의
# O 경기를 경기를
# O 통해 통해
# O 형의 형의
# O 풍신을 풍신을
# O 보여주겠다며 보여주겠다며
# O 다짐이 다짐이
# O 대단하다 대단하다
# O . .
# O 만리경이 만리경이
# O 고정돼 고정돼
# O 있고 있고
# O 대괴와 대괴와
# O 동류인 동류인
# O 빠르기로 빠르기로
# O 돌아간다고 돌아간다고
# O 혹정해 혹정해
# O 보면요, 보면요,
# O 별에서 별에서
# O 나오는 나오는
# O 빛이 빛이
# O 여기 여기
# O 초면에 초면에
# O 보이는 보이는
# O 것처럼 것처럼
# O 길게 길게
# O 잔재를 잔재를
# O 남기게 남기게
# O 됩니다 됩니다
# O . .
# O 핵심기자재인 핵심기자재인
# O 증발기 증발기
# O 제작에 제작에
# O 있어서 있어서
# O 두우 두우
# O 최단납기인 최단납기인
# DAT_B 12개월을 12개월을
# O 보지하고 보지하고
# O 있어 있어
# O 경쟁력을 경쟁력을
# O 견지하고 견지하고
# O 있습니다 있습니다
# O . .
# O -야구촬영을 -야구촬영을
# O 저희가 저희가
# DAT_B 두 두
# O 달, 달,
# O 세 세
# O 달 달
# O 야구장에서 야구장에서
# O 살았던 살았던
# O 것 것
# O 같아요 같아요
# O . .
# O 확대경영 확대경영
# O 나선 나선
# O 하버드대 하버드대
# O 프롬폼 프롬폼
# O 기싸움에서 기싸움에서
# O 밀리지 밀리지
# O 않겠다는 않겠다는
# O 양팀 양팀
# O 장의자의 장의자의
# O 분위기는 분위기는
# O 플레이오프 플레이오프
# O 못지않은 못지않은
# O 열기를 열기를
# O 내뿜었다 내뿜었다
# O . .
# O 그러한데도 그러한데도
# O 못했다면 못했다면
# O 불녕 불녕
# O 책임이다 책임이다
# O . .
# O 백융기 백융기
# O 첩장은 첩장은
# O “LG의 “LG의
# O 노서아 노서아
# O 상업이 상업이
# O 활성화될 활성화될
# O 것으로 것으로
# O 기대한다”며 기대한다”며
# O “LG가 “LG가
# O 덕곡리에서 덕곡리에서
# O 이자 이자
# O 브랜드로 브랜드로
# O 자리잡을 자리잡을
# O 수 수
# O 있도록 있도록
# O 분발해 분발해
# O 달라”고 달라”고
# O 당부했다 당부했다
# O . .
# O 득점 득점
# O 정황도 정황도
# O 운이 운이
# O 없었을 없었을
# O 뿐이었다 뿐이었다
# O . .
# O 시력장애 시력장애
# O 킹카에게 킹카에게
# O 식물성스테롤을 식물성스테롤을
# O 흡수하게 흡수하게
# O 했더니 했더니
# DAT_B 3주 3주
# O 뒤 뒤
# O 몸의 몸의
# O 나쁜 나쁜
# O 콜레스테롤이 콜레스테롤이
# O 줄어들은 줄어들은
# O 열매가 열매가
# O 나왔다 나왔다
# O . .
# O 아， 아，
# O 이렇게 이렇게
# O 아름다운 아름다운
# O 꽃들이 꽃들이
# O 있습니다 있습니다
# O ． ．
# O 주증상인 주증상인
# O 보충을 보충을
# O 위해 위해
# O 용대연못에서 용대연못에서
# O 쉬퍼 쉬퍼
# O 히로키도 히로키도
# O 불러왔다 불러왔다
# O ． ．
# O 개각 개각
# O 승상은 승상은
# O 정보통신부 정보통신부
# O · ·
# O 홍대 홍대
# O · ·
# O 해양수산부 해양수산부
# O · ·
# O 후생노동청 후생노동청
# O · ·
# O 환경부 환경부
# O 등이며 등이며
# O 국무조정실은 국무조정실은
# O 개각 개각
# O 여부가 여부가
# O 불확실하다 불확실하다
# O . .
# O 임신부구 임신부구
# O 밖에서의 밖에서의
# O 활동은 활동은
# O 빛난다 빛난다
# O . .
# O -(해설) -(해설)
# O 창의성은 창의성은
# O 하루아침에 하루아침에
# O 길러지지 길러지지
# O 않는다 않는다
# O . .
# O -(해설) -(해설)
# O 심하기는 심하기는
# O 하네요 하네요
# O . .
# O 폐기종 폐기종
# O 샷의 샷의
# O 요령은 요령은
# O 풀스윙으로 풀스윙으로
# O 칩샷한다는 칩샷한다는
# O 마음과도 마음과도
# O 마찬가지일거예요 마찬가지일거예요
# O . .
# DAT_B ◇10년간 ◇10년간
# O 음반 음반
# O 상점 상점
# O 존명율 존명율
# O 7%=사단법인 7%=사단법인
# O 사이버테러대응센터(회장 사이버테러대응센터(회장
# O 박지현)의 박지현)의
# O 감사에 감사에
# O 따르면 따르면
# DAT_B 10년 10년
# O 조야 조야
# O 1884여개에 1884여개에
# O 이르렀던 이르렀던
# O 녹음 녹음
# O 전한 전한
# O 수가 수가
# DAT_B 4년에는 4년에는
# O 17개로 17개로
# O 줄었다 줄었다
# O . .
# O ‘본좌’ ‘본좌’
# O ‘몽상가’ ‘몽상가’
# O 로댕, 로댕,
# O ‘폭풍저그’ ‘폭풍저그’
# O 최창환호가 최창환호가
# O 금반엔 금반엔
# O 아메리카합중국 아메리카합중국
# O 노르나에서 노르나에서
# O 맞붙는다 맞붙는다
# O . .
# O -사랑하는 -사랑하는
# O 정남을 정남을
# O 왕으로 왕으로
# O 모시겠다는 모시겠다는
# O 백순근의 백순근의
# O 양치기에 양치기에
# O 많은 많은
# O 여성분들이 여성분들이
# O 반하셨을 반하셨을
# O 텐데요 텐데요
# O . .
# O 게임방식은 게임방식은
# O 초보농부구 초보농부구
# O 한 한
# O 게임 게임
# O 23~3세트 23~3세트
# O 수신기별 수신기별
# O 점수차를 점수차를
# O 알아 알아
# O 맞히는 맞히는
# O 것으로 것으로
# O 승리팀은 승리팀은
# O 홈팀 홈팀
# O . .
# O 이런 이런
# O 흐름으로 흐름으로
# O 유행기가 유행기가
# O 영속된다면 영속된다면
# DAT_B 안해보다 안해보다
# O 11타수 11타수
# O 나중 나중
# O 13구 13구
# O 이내에 이내에
# O 수영을 수영을
# O 걸게된다는 걸게된다는
# O 뜻이 뜻이
# O 된다 된다
# O . .
# O 그들과 그들과
# O 접할 접할
# O 호기도 호기도
# O 없었던 없었던
# O 탓에 탓에
# O 타국 타국
# O 정신문화에 정신문화에
# O 대해 대해
# O 알지 알지
# O 못했다"라며 못했다"라며
# O "통독 "통독
# O 이사 이사
# O 과목 과목
# O 서독지역으로 서독지역으로
# O 넘어온 넘어온
# O 이후에는 이후에는
# O 많은 많은
# O 자치행정감사국장들을 자치행정감사국장들을
# O 접하면서 접하면서
# O 해외 해외
# O 정신문화에 정신문화에
# O 대해서도 대해서도
# O 어느정도 어느정도
# O 이해하게 이해하게
# O 됐다"고 됐다"고
# O 해석했다 해석했다
# O . .
# O 삼성화재 삼성화재
# O 러셀 러셀
# O 산모 산모
# DAT_B "다음주 "다음주
# O 개막전이 개막전이
# O 중요" 중요"
# O -(해설) -(해설)
# O 따개비는 따개비는
# O 물 물
# O 속에 속에
# O 들어가면 들어가면
# O 뚜껑을 뚜껑을
# O 열고 열고
# O 긴 긴
# O 털을 털을
# O 내밀어서 내밀어서
# O 플랑크톤을 플랑크톤을
# O 잡아먹습니다 잡아먹습니다
# O . .
# O 서귀포시선거관리위원회 서귀포시선거관리위원회
# O 현대미포조선 현대미포조선
# O 29-1 29-1
# O 헌재 헌재
# O KB국민은행 KB국민은행
# O . .
# DAT_B 6년 6년
# O 전 전
# O 이들의 이들의
# O 테러음모를 테러음모를
# O 장악한 장악한
# O FBI는 FBI는
# O 스케이트화를 스케이트화를
# O 통해 통해
# O 이들에게 이들에게
# O 작동하지 작동하지
# O 않는 않는
# O 진물 진물
# O 미사일을 미사일을
# O 건넨 건넨
# O 것으로 것으로
# O 전해졌습니다 전해졌습니다
# O . .
# O 김석 김석
# O 김시무니 김시무니
# O 둘뿐이다 둘뿐이다
# O . .
# O 야근자: 야근자:
# DAT_B 6년 6년
# O 발자취를 발자취를
# O 과긍하는 과긍하는
# O 코믹콘은 코믹콘은
# O 영향력이 영향력이
# O 커지면서 커지면서
# O 범부처방문단 범부처방문단
# O 감독들이 감독들이
# O 찾아야 찾아야
# O 할 할
# O 축제로 축제로
# O 자리매김했습니다 자리매김했습니다
# O . .
# O 이륙한 이륙한
# O 지 지
# DAT_B 3일 3일
# O 뒷면 뒷면
# O 우주선은 우주선은
# O 달 달
# O 근처의 근처의
# O 차도에 차도에
# O 진입하게 진입하게
# O 됩니다 됩니다
# O . .
# O (이석무 (이석무
# O 감리비 감리비
# O smlee@mydaily.co.kr)[관련기사]▶ smlee@mydaily.co.kr)[관련기사]▶
# O ▶ ▶
# O ▶ ▶
# O ▶ ▶
# O ▶ ▶
# O 기마병 기마병
# O 제보 제보
# O 및 및
# O 보도자료 보도자료
# O 우세승 우세승
# O 닛산자동차 닛산자동차
# O 1175 1175
# O NATE/magicⓝ/ez-i- NATE/magicⓝ/ez-i-
# O NO1.뉴미디어 NO1.뉴미디어
# O 실시간 실시간
# O 뉴스 뉴스
# O 마이데일리() 마이데일리()
# O 심판이사 심판이사
# O ⓒ ⓒ
# O 국립과학센터 국립과학센터
# O . .
# O 그는 그는
# O 레노버가 레노버가
# DAT_B 지난 지난
# O 1월 1월
# O IBM IBM
# O PC PC
# O 현대엘리베이터를 현대엘리베이터를
# O 승자하며 승자하며
# O 영입한 영입한
# O 김대은 김대은
# O 최준우 최준우
# O 전 전
# O IBM에서 IBM에서
# DAT_B 7년 7년
# O 동안 동안
# O 일했다 일했다
# O . .
# O 미움도 미움도
# O 열심성이고 열심성이고
# O 일도 일도
# O 열심성이고 열심성이고
# O . .
# O －（해설） －（해설）
# O 어째 어째
# O 뭔가 뭔가
# O 수상쩍은 수상쩍은
# O 좌담 좌담
# O ． ．

# %%
# 전처리 10분 이상 걸려서 로컬에 따로 저장

from google.colab import drive
import pickle

# Google 드라이브 마운트
drive.mount('/content/drive')

# 저장할 파일 경로
file_path = "/content/drive/My Drive/Colab Notebooks/naver_data.pkl"

# 데이터를 pickle 파일에 저장
with open(file_path, "wb") as f:
    pickle.dump((naver_text, naver_tags), f)

print("파일이 Google 드라이브에 저장되었습니다.")
# Out:
# Mounted at /content/drive
# 파일이 Google 드라이브에 저장되었습니다.

# %%
from google.colab import drive
import pickle

# Google 드라이브 마운트
drive.mount('/content/drive')

# 불러올 파일 경로
file_path = "/content/drive/My Drive/Colab Notebooks/naver_data.pkl"

# pickle 파일에서 데이터 불러오기
with open(file_path, "rb") as f:
    naver_text, naver_tags = pickle.load(f)

print("파일이 성공적으로 불러와졌습니다.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 파일이 성공적으로 불러와졌습니다.

# %%
print(len(naver_text))
print(len(naver_tags))
# Out:
# 90000
# 90000

# %%
print(naver_text[7], end='\n\n') # 음절 단위로 잘 잘렸네요!
print(naver_tags[7])
# Out:
# ['금', '반', '명', '기', '통', '합', '우', '승', '2', '4', ',', '1', '0', '회', '차', '는', '8', '일', '상', '오', '6', '시', '5', '0', '분', ',', '상', '오', '1', '1', '시', '5', '0', '분', '에', '발', '태', '가', '끝', '마', '감', '되', '며', ',', '비', '공', '식', '적', '중', '결', '과', '는', '5', '일', '공', '표', '된', '다', '.']
#
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'DAT_B', 'DAT_B', 'TIM_B', 'TIM_B', 'O', 'O', 'O', 'O', 'O', 'O', 'TIM_B', 'TIM_B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'DAT_B', 'DAT_B', 'O', 'O', 'O', 'O', 'O']

# %% [markdown]
# 해양 뭐시기 데이터셋 전처리

# %%
import re
def read_file(file_list):
    token_docs = []
    tag_docs = []
    for file_path in file_list:
        file_path = Path(file_path)
        raw_text = file_path.read_text().strip()
        raw_docs = re.split(r'\n\t?\n', raw_text)

        for doc in raw_docs:
            tokens = []
            tags = []
            for line in doc.split('\n'):
                if line[0:1] == "$" or line[0:1] == ";" or line[0:2] == "##":
                    continue
                token = line.split('\t')[0]
                tag = line.split('\t')[3]
                for i, syllable in enumerate(token):    # 음절 단위로 잘라서
                    tokens.append(syllable)
                    tags.append(tag)

            token_docs.append(tokens)
            tag_docs.append(tags)

    return token_docs, tag_docs

# %%
texts, tags = read_file(file_list[:])

# %%
print(len(texts))
print(len(tags))
# Out:
# 19263
# 19263

# %%
print(texts[0], end='\n\n') # 음절 단위로 잘 잘렸네요!
print(tags[0])
# Out:
# ['오', '에', '_', '겐', '자', '부', '로', '는', '_', '일', '본', '_', '현', '대', '문', '학', '의', '_', '초', '석', '을', '_', '놓', '은', '_', '것', '으', '로', '_', '평', '가', '받', '는', '_', '작', '가', '_', '나', '쓰', '메', '_', '소', '세', '키', '(', '1', '8', '6', '7', '~', '1', '9', '1', '6', ')', '의', '_', '대', '표', '작', '_', '‘', '마', '음', '’', '에', '_', '담', '긴', '_', '군', '국', '주', '의', '적', '_', '요', '소', ',', '_', '야', '스', '쿠', '니', '_', '신', '사', '_', '참', '배', '_', '행', '위', '까', '지', '_', '소', '설', '의', '_', '삽', '화', '로', '_', '동', '원', '하', '며', '_', '일', '본', '_', '사', '회', '의', '_', '‘', '비', '정', '상', '성', '’', '을', '_', '문', '제', '_', '삼', '는', '다', '.']
#
# ['B-PER', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-LOC', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'B-PER', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-DUR', 'B-DUR', 'B-DUR', 'B-DUR', 'I-DUR', 'I-DUR', 'I-DUR', 'I-DUR', 'I-DUR', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-POH', 'B-POH', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'B-ORG', 'B-ORG', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %% [markdown]
# 분리된 토큰을 하나의 개체명으로 묶어 주는 태깅 시스템을 위해 있는게 BIO, BIESO임.
#
# 여러 개의 토큰으로 이루어진 개체명의 경우
#
# **개체명이 시작할 때** 'B,begin'
#
# **토큰이 개체명 중간에 있을 때** 'I,inside'
#
# **개체명의 마지막에 위치할 때** 'E,end'
#
# **하나의 토큰이 곧 하나의 개체명일 때** 'S,singleton'
#
# **토큰이 개체명이 아닐 경우** 'O,outside'

# %%
unique_tags = set(tag for doc in tags for tag in doc)
tag2id = {tag: id for id, tag in enumerate(unique_tags)}
id2tag = {id: tag for tag, id in tag2id.items()}

for i, tag in enumerate(unique_tags):
    print(tag)  #해양 tags 변경 전
# Out:
# I-LOC
# I-DAT
# B-PER
# I-DUR
# I-MNY
# I-PNT
# B-DAT
# B-POH
# B-LOC
# I-NOH
# B-NOH
# O
# B-ORG
# I-POH
# B-MNY
# I-ORG
# I-TIM
# B-DUR
# B-TIM
# I-PER
# B-PNT

# %%
# for sublist in tags:
#     for i, label in enumerate(sublist):
#         if label == 'I-NOH':
#             sublist[i] = 'NOH_I'
#         elif label == 'I-PNT':
#             sublist[i] = 'PNT_I'
#         elif label == 'I-ORG':
#             sublist[i] = 'ORG_I'
#         elif label == 'I-DUR':
#             sublist[i] = 'DUR_I'
#         elif label == 'I-TIM':
#             sublist[i] = 'TIM_I'
#         elif label == 'I-PER':
#             sublist[i] = 'PER_I'
#         elif label == 'I-MNY':
#             sublist[i] = 'MNY_I'
#         elif label == 'B-MNY':
#             sublist[i] = 'MNY_B'
#         elif label == 'B-DAY':
#             sublist[i] = 'DAY_B'
#         elif label == 'B-TIM':
#             sublist[i] = 'TIM_B'
#         elif label == 'I-LOC':
#             sublist[i] = 'LOC_I'
#         elif label == 'B-PER':
#             sublist[i] = 'PER_B'
#         elif label == 'B-ORG':
#             sublist[i] = 'ORG_B'
#         elif label == 'B-LOC':
#             sublist[i] = 'LOC_B'
#         elif label == 'B-PNT':
#             sublist[i] = 'PNT_B'
#         elif label == 'B-NOH':
#             sublist[i] = 'NOH_B'
#         elif label == 'I-PER':
#             sublist[i] = 'PER_I'
#         elif label == 'B-LOC':
#             sublist[i] = 'LOC_B'
#         elif label == 'I-POH':
#             sublist[i] = 'POH_I'
#         elif label == 'I-DAT':
#             sublist[i] = 'DAT_I'
#         elif label == 'B-POH':
#             sublist[i] = 'POH_B'
#         elif label == 'B-DUR':
#             sublist[i] = 'DUR_B'
#         elif label == 'B-DAT':
#             sublist[i] = 'DAT_B'
#         elif label == '0':
#             sublist[i] = '0'

# %%
# DUR, DAT, TIM 만 남김
for sublist in tags:
    for i, label in enumerate(sublist):
        if label == 'I-NOH':
            sublist[i] = '0'
        elif label == 'I-PNT':
            sublist[i] = '0'
        elif label == 'I-ORG':
            sublist[i] = '0'
        elif label == 'I-DUR':
            sublist[i] = 'DUR_B' # DUR
        elif label == 'I-TIM':
            sublist[i] = 'TIM_B' # TIM
        elif label == 'I-PER':
            sublist[i] = '0'
        elif label == 'I-MNY':
            sublist[i] = 'O'
        elif label == 'B-MNY':
            sublist[i] = 'O'
        elif label == 'B-DAY':
            sublist[i] = 'O'
        elif label == 'B-TIM':
            sublist[i] = 'TIM_B' # TIM
        elif label == 'I-LOC':
            sublist[i] = 'O'
        elif label == 'B-PER':
            sublist[i] = 'O'
        elif label == 'B-ORG':
            sublist[i] = 'O'
        elif label == 'B-LOC':
            sublist[i] = 'O'
        elif label == 'B-PNT':
            sublist[i] = 'O'
        elif label == 'B-NOH':
            sublist[i] = 'O'
        elif label == 'I-PER':
            sublist[i] = 'O'
        elif label == 'B-LOC':
            sublist[i] = 'O'
        elif label == 'I-POH':
            sublist[i] = 'O'
        elif label == 'I-DAT':
            sublist[i] = 'DAT_B' # DAT
        elif label == 'B-POH':
            sublist[i] = 'O'
        elif label == 'B-DUR':
            sublist[i] = 'DUR_B' # DUR
        elif label == 'B-DAT':
            sublist[i] = 'DAT_B' # DAT
        elif label == '0':
            sublist[i] = '0'

# %%
unique_tags = set(tag for doc in tags for tag in doc)
tag2id = {tag: id for id, tag in enumerate(unique_tags)}
id2tag = {id: tag for tag, id in tag2id.items()}

for i, tag in enumerate(unique_tags):
    print(tag)  #해양 tags 변경 후
# Out:
# O
# DUR_B
# TIM_B
# DAT_B
# 0

# %%
texts.extend(naver_text)
tags.extend(naver_tags)

# %%
unique_tags = set(tag for doc in tags for tag in doc)
tag2id = {tag: id for id, tag in enumerate(unique_tags)}
id2tag = {id: tag for tag, id in tag2id.items()}

# %%
for i, tag in enumerate(unique_tags):
    print(tag)  # 학습을 위한 label list를 확인합니다.
# Out:
# O
# DUR_B
# TIM_B
# DAT_B
# 0

# %%
for tag in list(tag2id.keys()) :
    globals()[tag] = 0

for tag in tags :
    for ner in tag :
        globals()[ner] += 1

for tag in list(tag2id.keys()) :
    print('{:>6} : {:>7,}'. format(tag, globals()[tag]))
# Out:
#      O : 4,670,727
#  DUR_B :   5,780
#  TIM_B :  12,707
#  DAT_B :  97,934
#      0 :  42,181

# %%
from sklearn.model_selection import train_test_split
train_texts, test_texts, train_tags, test_tags = train_test_split(texts, tags, test_size=.2, random_state=42)

# %%
print('Train 문장 : {:>6,}' .format(len(train_texts)))
print('Train 태그 : {:>6,}' .format(len(train_tags)))
print('Test  문장 : {:>6,}' .format(len(test_texts)))
print('Test  태그 : {:>6,}' .format(len(test_tags)))
# Out:
# Train 문장 : 87,410
# Train 태그 : 87,410
# Test  문장 : 21,853
# Test  태그 : 21,853

# %%
train_texts[5]
# Out:
# ['첫',
#  '출',
#  '발',
#  '남',
#  '상',
#  '은',
#  '작',
#  '은',
#  '어',
#  '간',
#  '하',
#  '나',
#  '였',
#  '어',
#  '요',
#  '.']

# %% [markdown]
# BERT 토크나이저

# %%
from transformers import AutoModel, AutoTokenizer, BertTokenizer
MODEL_NAME = "beomi/KcELECTRA-base-v2022"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
unique_tags = set(tag for doc in tags for tag in doc)
tag2id = {tag: id for id, tag in enumerate(unique_tags)}
id2tag = {id: tag for tag, id in tag2id.items()}

# %%
pad_token_id = tokenizer.pad_token_id # 0
cls_token_id = tokenizer.cls_token_id # 101
sep_token_id = tokenizer.sep_token_id # 102
pad_token_label_id = tag2id['O']    # tag2id['O']
cls_token_label_id = tag2id['O']
sep_token_label_id = tag2id['O']

# %%
def ner_tokenizer(sent, max_seq_length):
    pre_syllable = "_"
    input_ids = [pad_token_id] * (max_seq_length - 1)
    attention_mask = [0] * (max_seq_length - 1)
    token_type_ids = [0] * max_seq_length
    sent = sent[:max_seq_length-2]

    for i, syllable in enumerate(sent):
        if syllable == '_':
            pre_syllable = syllable
        if pre_syllable != "_":
            syllable = '##' + syllable  # 중간 음절에는 모두 prefix를 붙입니다.
            # 우리가 구성한 학습 데이터도 이렇게 구성되었기 때문이라고 함.
            # 이순신은 조선 -> [이, ##순, ##신, ##은, 조, ##선]
        pre_syllable = syllable

        input_ids[i] = (tokenizer.convert_tokens_to_ids(syllable))
        attention_mask[i] = 1

    input_ids = [cls_token_id] + input_ids
    input_ids[len(sent)+1] = sep_token_id
    attention_mask = [1] + attention_mask
    attention_mask[len(sent)+1] = 1
    return {"input_ids":input_ids,
            "attention_mask":attention_mask,
            "token_type_ids":token_type_ids}

# %%
print(ner_tokenizer(train_texts[0], 5))
# Out:
# {'input_ids': [2, 1912, 4044, 4040, 3], 'attention_mask': [1, 1, 1, 1, 1], 'token_type_ids': [0, 0, 0, 0, 0]}

# %%
tokenized_train_sentences = []
tokenized_test_sentences = []

for text in train_texts:    # 전체 데이터를 tokenizing 합니다.
    tokenized_train_sentences.append(ner_tokenizer(text, 128))
for text in test_texts:
    tokenized_test_sentences.append(ner_tokenizer(text, 128))

# %%
def encode_tags(tags, max_seq_length):
    # label 역시 입력 token과 개수를 맞춰줍니다
    tags = tags[:max_seq_length-2]
    labels = [tag2id[tag] for tag in tags]
    labels = [tag2id['O']] + labels

    padding_length = max_seq_length - len(labels)
    labels = labels + ([pad_token_label_id] * padding_length)

    return labels

# %%
tag2id
# Out:
# {'O': 0, 'DUR_B': 1, 'TIM_B': 2, 'DAT_B': 3, '0': 4}

# %%
encode_tags(train_tags[0], 5)
# Out:
# [0, 0, 0, 0, 0]

# %%
train_labels = []
test_labels = []

for tag in train_tags:
    train_labels.append(encode_tags(tag, 128))

for tag in test_tags:
    test_labels.append(encode_tags(tag, 128))

# %%
len(train_labels), len(test_labels)
# Out:
# (87410, 21853)

# %% [markdown]
# Token 데이터셋

# %%
import torch

class TokenDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val) for key, val in self.encodings[idx].items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = TokenDataset(tokenized_train_sentences, train_labels)
test_dataset = TokenDataset(tokenized_test_sentences, test_labels)

# %%
# !pip install transformers==4.30
# !pip install -U accelerate
# Out:
# Collecting transformers==4.30
#   Downloading transformers-4.30.0-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 29.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 75.1 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30) (2024.2.2)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.40.2
#     Uninstalling transformers-4.40.2:
#       Successfully uninstalled transformers-4.40.2
# Successfully installed tokenizers-0.13.3 transformers-4.30.0
# Collecting accelerate
#   Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# ERROR: Operation cancelled by user

# %%
from transformers import BertForTokenClassification, Trainer, TrainingArguments, AutoModelForTokenClassification,EarlyStoppingCallback
import sys
training_args = TrainingArguments(
    output_dir='./results',          # output directory
    num_train_epochs=5,              # total number of training epochs
    per_device_train_batch_size=8,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    logging_dir='./logs',            # directory for storing logs
    logging_steps=1000, # 1000번쨰 steps마다 log를 보여줌
    learning_rate=3e-5,
    weight_decay=0.01,
    save_total_limit=5,
    save_strategy='steps', # steps로 해야 earlystop이 가능
    evaluation_strategy='steps',
    save_steps=1000, # 1000번쨰 step마다 저장
    eval_steps=1000, # 1000번째 step마다 평가
    seed=15,
    load_best_model_at_end=True # 가장 좋은 성능의 모델로...
)

# %% [markdown]
# BertForTokenClassification

# %%
model = AutoModelForTokenClassification.from_pretrained(MODEL_NAME, num_labels=len(unique_tags))
model.to(device)

trainer = Trainer(
    model=model,                         # the instantiated 🤗 Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=test_dataset,# evaluation dataset
    callbacks = [EarlyStoppingCallback(early_stopping_patience=2)] #loss가 2번 감소하지 않으면 스탑
)
# Out:
# pytorch_model.bin:   0%|          | 0.00/511M [00:00<?, ?B/s]
# Some weights of the model checkpoint at beomi/KcELECTRA-base-v2022 were not used when initializing ElectraForTokenClassification: ['discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForTokenClassification were not initialized from the model checkpoint at beomi/KcELECTRA-base-v2022 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import gc
gc.collect()
# Out:
# 30

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='1551' max='54635' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 1551/54635 08:23 < 4:47:45, 3.07 it/s, Epoch 0.14/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.035600</td>
#       <td>0.018020</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='3001' max='54635' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 3001/54635 16:23 < 4:42:09, 3.05 it/s, Epoch 0.27/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.035600</td>
#       <td>0.018020</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.017600</td>
#       <td>0.014568</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='78' max='342' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 78/342 00:36 < 02:05, 2.10 it/s]
#     </div>

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='18001' max='54635' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18001/54635 1:48:53 < 3:41:37, 2.76 it/s, Epoch 1.65/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.347600</td>
#       <td>0.229978</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.215900</td>
#       <td>0.182514</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.182000</td>
#       <td>0.169995</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.171000</td>
#       <td>0.155971</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.161600</td>
#       <td>0.148856</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.148200</td>
#       <td>0.138977</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.148600</td>
#       <td>0.134349</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.143800</td>
#       <td>0.131404</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.142300</td>
#       <td>0.127040</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.134500</td>
#       <td>0.126455</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.132000</td>
#       <td>0.120538</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.110100</td>
#       <td>0.119461</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.106700</td>
#       <td>0.120201</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.110000</td>
#       <td>0.118696</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.107400</td>
#       <td>0.115921</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.104000</td>
#       <td>0.115880</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.103100</td>
#       <td>0.116491</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='471' max='342' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [342/342 04:02]
#     </div>
#     <div>
#
#       <progress value='23' max='54635' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   23/54635 00:05 < 3:37:16, 4.19 it/s, Epoch 0.00/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>22</td>
#       <td>No log</td>
#       <td>0.111767</td>
#     </tr>
#   </tbody>
# </table><p>
# {'eval_loss': 0.11176680028438568}

# %%
predictions = trainer.predict(test_dataset)
print(predictions.predictions.shape, predictions.label_ids.shape)
# Out:
#     <div>
#
#       <progress value='23' max='54635' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   23/54635 00:05 < 3:37:16, 4.19 it/s, Epoch 0.00/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>22</td>
#       <td>No log</td>
#       <td>0.111767</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='342' max='342' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [342/342 02:34]
#     </div>
# (21853, 128, 39) (21853, 128)

# %%
import numpy as np

preds = np.argmax(predictions.predictions, axis=-1)

# %%
index_to_ner = {i:j for j, i in tag2id.items()}
f_label = [i for i, j in tag2id.items()]
val_tags_l = [index_to_ner[x] for x in np.ravel(predictions.label_ids).astype(int).tolist()]
y_predicted_l = [index_to_ner[x] for x in np.ravel(preds).astype(int).tolist()]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# %%
#데이터셋 추가
print(classification_report(val_tags_l, y_predicted_l, labels=f_label))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        POH_B       0.63      0.58      0.60      3333
#        CVL_B       0.78      0.81      0.79     51705
#        FLD_B       0.60      0.44      0.51      2046
#        FLD_I       0.00      0.00      0.00        29
#        EVT_I       0.70      0.74      0.72      6233
#        AFW_B       0.71      0.43      0.53      4589
#        CVL_I       0.45      0.34      0.39      2798
#        NUM_B       0.93      0.93      0.93     45374
#        MAT_I       0.00      0.00      0.00        26
#        TIM_I       0.84      0.85      0.84       959
#        ANM_I       0.00      0.00      0.00        30
#        PER_I       0.69      0.68      0.69      6533
#        POH_I       0.71      0.62      0.66      5117
#        TRM_I       0.46      0.38      0.42      2574
#        TIM_B       0.81      0.80      0.81      2117
#        ANM_B       0.74      0.68      0.71      4497
#            O       0.99      0.99      0.99   2450478
#        DAT_I       0.83      0.92      0.87      5611
#        DUR_I       0.60      0.77      0.68       681
#        PNT_B       0.88      0.96      0.91       771
#        PNT_I       0.92      0.93      0.92       303
#        MNY_I       0.97      0.99      0.98       948
#        EVT_B       0.78      0.75      0.76     11622
#        ORG_I       0.62      0.61      0.61      8988
#        MNY_B       0.98      0.98      0.98       744
#        ORG_B       0.84      0.78      0.81     53683
#        LOC_B       0.68      0.80      0.74     22561
#        PLT_I       0.00      0.00      0.00         0
#        MAT_B       0.00      0.00      0.00       213
#        DAT_B       0.92      0.90      0.91     17646
#        NUM_I       0.64      0.66      0.65      5294
#        AFW_I       0.67      0.47      0.55      1975
#        PLT_B       0.00      0.00      0.00       173
#        DUR_B       0.67      0.64      0.65       412
#        PER_B       0.84      0.86      0.85     42838
#        LOC_I       0.54      0.36      0.43      1661
#        NOH_B       0.90      0.91      0.91      3807
#        TRM_B       0.80      0.79      0.79     25492
#        NOH_I       0.86      0.89      0.87      3323
#
#    micro avg       0.97      0.97      0.97   2797184
#    macro avg       0.64      0.62      0.63   2797184
# weighted avg       0.97      0.97      0.97   2797184
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
trainer.save_model('kcelectra_base_new')

# %%
id2tag.values()
# Out:
# dict_values(['POH_B', 'CVL_B', 'FLD_B', 'FLD_I', 'EVT_I', 'AFW_B', 'CVL_I', 'NUM_B', 'MAT_I', 'TIM_I', 'ANM_I', 'PER_I', 'POH_I', 'TRM_I', 'TIM_B', 'ANM_B', 'O', 'DAT_I', 'DUR_I', 'PNT_B', 'PNT_I', 'MNY_I', 'EVT_B', 'ORG_I', 'MNY_B', 'ORG_B', 'LOC_B', 'PLT_I', 'MAT_B', 'DAT_B', 'NUM_I', 'AFW_I', 'PLT_B', 'DUR_B', 'PER_B', 'LOC_I', 'NOH_B', 'TRM_B', 'NOH_I'])

# %%
# 저장한 모델 불러오기
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

from transformers import AutoModel, AutoTokenizer, BertTokenizer
MODEL_NAME = "beomi/KcELECTRA-base-v2022"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

tag2id = {'POH_B': 0, 'CVL_B': 1, 'FLD_B': 2, 'FLD_I': 3, 'EVT_I': 4,'AFW_B': 5,'CVL_I': 6,'NUM_B': 7,'MAT_I': 8, 'TIM_I': 9,'ANM_I': 10,'PER_I': 11,'POH_I': 12,
 'TRM_I': 13,
 'TIM_B': 14,
 'ANM_B': 15,
 'O': 16,
 'DAT_I': 17,
 'DUR_I': 18,
 'PNT_B': 19,
 'PNT_I': 20,
 'MNY_I': 21,
 'EVT_B': 22,
 'ORG_I': 23,
 'MNY_B': 24,
 'ORG_B': 25,
 'LOC_B': 26,
 'PLT_I': 27,
 'MAT_B': 28,
 'DAT_B': 29,
 'NUM_I': 30,
 'AFW_I': 31,
 'PLT_B': 32,
 'DUR_B': 33,
 'PER_B': 34,
 'LOC_I': 35,
 'NOH_B': 36,
 'TRM_B': 37,
 'NOH_I': 38}
unique_tags={'POH_B', 'CVL_B', 'FLD_B', 'FLD_I', 'EVT_I', 'AFW_B', 'CVL_I', 'NUM_B', 'MAT_I', 'TIM_I', 'ANM_I', 'PER_I', 'POH_I', 'TRM_I', 'TIM_B', 'ANM_B', 'O', 'DAT_I', 'DUR_I', 'PNT_B', 'PNT_I', 'MNY_I', 'EVT_B', 'ORG_I', 'MNY_B', 'ORG_B', 'LOC_B', 'PLT_I', 'MAT_B', 'DAT_B', 'NUM_I', 'AFW_I', 'PLT_B', 'DUR_B', 'PER_B', 'LOC_I', 'NOH_B', 'TRM_B', 'NOH_I'}
id2tag={0: 'POH_B',
 1: 'CVL_B',
 2: 'FLD_B',
 3: 'FLD_I',
 4: 'EVT_I',
 5: 'AFW_B',
 6: 'CVL_I',
 7: 'NUM_B',
 8: 'MAT_I',
 9: 'TIM_I',
 10: 'ANM_I',
 11: 'PER_I',
 12: 'POH_I',
 13: 'TRM_I',
 14: 'TIM_B',
 15: 'ANM_B',
 16: 'O',
 17: 'DAT_I',
 18: 'DUR_I',
 19: 'PNT_B',
 20: 'PNT_I',
 21: 'MNY_I',
 22: 'EVT_B',
 23: 'ORG_I',
 24: 'MNY_B',
 25: 'ORG_B',
 26: 'LOC_B',
 27: 'PLT_I',
 28: 'MAT_B',
 29: 'DAT_B',
 30: 'NUM_I',
 31: 'AFW_I',
 32: 'PLT_B',
 33: 'DUR_B',
 34: 'PER_B',
 35: 'LOC_I',
 36: 'NOH_B',
 37: 'TRM_B',
 38: 'NOH_I'}
pad_token_id = tokenizer.pad_token_id # 0
cls_token_id = tokenizer.cls_token_id # 101
sep_token_id = tokenizer.sep_token_id # 102
pad_token_label_id = tag2id['O']    # tag2id['O']
cls_token_label_id = tag2id['O']
sep_token_label_id = tag2id['O']

model = AutoModelForTokenClassification.from_pretrained('kcelectra_base_new', num_labels=len(unique_tags))
model.to(device)
# Out:
# ElectraForTokenClassification(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(54343, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=39, bias=True)
# )

# %%
# 기존 토크나이저는 wordPiece tokenizer로 tokenizing 결과를 반환합니다.
# 데이터 단위를 음절 단위로 변경했기 때문에, tokenizer도 음절 tokenizer로 변경

# berttokenizer를 사용하는데 한국어 vocab이 8000개 정도 밖에 없고 그 안의 한국어들의 거의 음절로 존재
# -> 음절 단위 tokenizer를 적용하면 vocab id를 어느 정도 획득할 수 있어 UNK가 별로 없을듯 하다
def ner_tokenizer(sent, max_seq_length):
    pre_syllable = "_"
    input_ids = [pad_token_id] * (max_seq_length - 1)
    attention_mask = [0] * (max_seq_length - 1)
    token_type_ids = [0] * max_seq_length
    sent = sent[:max_seq_length-2]

    for i, syllable in enumerate(sent):
        if syllable == '_':
            pre_syllable = syllable
        if pre_syllable != "_":
            syllable = '##' + syllable  # 중간 음절에는 모두 prefix를 붙입니다.
            # 우리가 구성한 학습 데이터도 이렇게 구성되었기 때문이라고 함.
            # 이순신은 조선 -> [이, ##순, ##신, ##은, 조, ##선]
        pre_syllable = syllable

        input_ids[i] = (tokenizer.convert_tokens_to_ids(syllable))
        attention_mask[i] = 1

    input_ids = [cls_token_id] + input_ids
    input_ids[len(sent)+1] = sep_token_id
    attention_mask = [1] + attention_mask
    attention_mask[len(sent)+1] = 1
    return {"input_ids":input_ids,
            "attention_mask":attention_mask,
            "token_type_ids":token_type_ids}

# %%
def ner_inference(text) :

    model.eval()
    text = text.replace(' ', '_')

    predictions , true_labels = [], []

    tokenized_sent = ner_tokenizer(text, len(text)+2)
    input_ids = torch.tensor(tokenized_sent['input_ids']).unsqueeze(0).to(device)
    attention_mask = torch.tensor(tokenized_sent['attention_mask']).unsqueeze(0).to(device)
    token_type_ids = torch.tensor(tokenized_sent['token_type_ids']).unsqueeze(0).to(device)

    with torch.no_grad():
        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids)

    logits = outputs['logits']
    logits = logits.detach().cpu().numpy()
    label_ids = token_type_ids.cpu().numpy()

    predictions.extend([list(p) for p in np.argmax(logits, axis=2)])
    true_labels.append(label_ids)

    pred_tags = [list(tag2id.keys())[p_i] for p in predictions for p_i in p]

    print('{}\t{}'.format("TOKEN", "TAG"))
    print("===========")
    # for token, tag in zip(tokenizer.decode(tokenized_sent['input_ids']), pred_tags):
    #   print("{:^5}\t{:^5}".format(token, tag))
    for i, tag in enumerate(pred_tags):
        print("{:^5}\t{:^5}".format(tokenizer.convert_ids_to_tokens(tokenized_sent['input_ids'][i]), tag))

# %%
text='모레 10시 반 안과 방문 예정, 시력 물어보기'

# %%
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   1  	DUR_B
#  ##2 	DUR_B
# [UNK]	DUR_I
#  ##2 	DUR_I
#  ##0 	DUR_I
# [UNK]	DUR_I
#  ##1 	DUR_I
#  ##2 	DUR_I
# [UNK]	DUR_I
#  ##2 	DUR_I
#  ##5 	DUR_I
#  ##일 	DUR_I
#  ##은 	  O
#   _  	  O
#   크  	POH_B
#  ##리 	POH_B
#  ##스 	POH_B
#  ##마 	POH_B
#  ##스 	POH_B
#   _  	POH_I
#   파  	POH_I
#  ##티 	  O
#  ##를 	  O
#   _  	  O
#   준  	  O
#  ##비 	  O
#  ##할 	  O
#  ##거 	  O
#  ##야 	  O
# [SEP]	  O
